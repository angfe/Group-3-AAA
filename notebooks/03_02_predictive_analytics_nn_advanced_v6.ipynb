# %% [markdown]
# # Predictive Analytics: Neural Network - Advanced Baseline v6
#
# => based on advanced baseline v5, select best model based on weighted criteria

# %%
import polars as pl
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from pathlib import Path
import math
import matplotlib.pyplot as plt

from run_config import MODELS_DIR, PATHS

from helper_functions import (
    get_torch_device,
    load_model_from_checkpoint,
    collect_predictions,
    compute_regression_metrics,
    plot_regression_diagnostics,
)

# %% [markdown]
# ## Preparations

# %%
# "Settings" / Decisions for the training data

SPATIAL_UNIT = "community_areas"
TIME_UNIT = "4h"
DATASET_STEM = f"GOLD_{TIME_UNIT.upper()}_DEMAND_{SPATIAL_UNIT.upper()}"
MODEL_TAG = f"{SPATIAL_UNIT}_{TIME_UNIT}"
TRAINING_DATA_PATH = PATHS.train_test_dir / f"{DATASET_STEM}_TRAIN.parquet"
VAL_DATA_PATH = PATHS.train_test_dir / f"{DATASET_STEM}_VAL.parquet"
MODEL_PATH = MODELS_DIR
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# Target and feature selection
TARGET_COL = "trip_count"
COMMUNITY_COL = "community_area"
EXCLUDE_COLS = [
    TARGET_COL,
    "datetime_hour",      # real timestamp would lead to much leakage
    "date",
    "_split_bucket",      # only used for splitting
    "month", # cyclic feature is used instead
    "weekday", # cyclic feature is used instead
    "hour", # cyclic feature is used instead
    # all other taxi data columns must be excluded to prevent leakage
    "trip_seconds_sum",
    "trip_seconds_mean",
    "trip_seconds_min",
    "trip_seconds_max",
    "trip_miles_sum",
    "trip_miles_mean",
    "trip_miles_min",
    "trip_miles_max",
    "fare_sum",
    "fare_mean",
    "fare_min",
    "fare_max",
    "tips_sum",
    "tips_mean",
    "tips_min",
    "tips_max",
    "tolls_sum",
    "tolls_mean",
    "tolls_min",
    "tolls_max",
    "extras_sum",
    "extras_mean",
    "extras_min",
    "extras_max",
    "trip_total_sum",
    "trip_total_mean",
    "trip_total_min",
    "trip_total_max",
    "most_common_payment_type",
]

# %% [markdown]
# ### Load the data and select features and target

# %%
# Load the tranining data
train_df = pl.scan_parquet(TRAINING_DATA_PATH)
val_df = pl.scan_parquet(VAL_DATA_PATH)

numeric_feature_cols = [
    col for col in train_df.collect_schema().names()
    if col not in EXCLUDE_COLS
    and col != COMMUNITY_COL
]

X_train_numeric = train_df.select(numeric_feature_cols).collect()
X_val_numeric = val_df.select(numeric_feature_cols).collect()

community_train_raw = (
    train_df.select(COMMUNITY_COL)
    .collect()
    .to_series()
    .to_numpy()
)

community_val_raw = (
    val_df.select(COMMUNITY_COL)
    .collect()
    .to_series()
    .to_numpy()
)

y_train = train_df.select(TARGET_COL).collect()
y_val = val_df.select(TARGET_COL).collect()

# %%
# Embedding
known_communities = sorted(np.unique(community_train_raw))

community_to_idx = {
    community_id: idx + 1
    for idx, community_id in enumerate(known_communities)
}

UNKNOWN_COMMUNITY_IDX = 0

community_train_idx = np.array(
    [community_to_idx.get(x, UNKNOWN_COMMUNITY_IDX)
     for x in community_train_raw],
    dtype=np.int64
)

community_val_idx = np.array(
    [community_to_idx.get(x, UNKNOWN_COMMUNITY_IDX)
     for x in community_val_raw],
    dtype=np.int64
)

num_communities = len(community_to_idx) + 1

print("Anzahl Embedding-Kategorien:", num_communities)
# Out:
# Anzahl Embedding-Kategorien: 78

# %% [markdown]
# Impotant, check datatype of features and target. Everything should be numerical. We already applied encoding to categorical features (e. g. cloud coverage), therefore all features are numerical.

# %%
def make_sample_weights(y_original):
    y = np.asarray(y_original).reshape(-1)

    weights = np.ones_like(y, dtype=np.float32)

    weights[(y > 0) & (y <= 2)] = 1.2
    weights[(y > 2) & (y <= 10)] = 1.5
    weights[(y > 10) & (y <= 20)] = 3.0
    weights[y > 20] = 5.0

    return weights

train_weights_np = make_sample_weights(y_train)

# %% [markdown]
# ### Scale the train data
#
# Important, the scaler is only fitted on X_train to prevent data leakage

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(
    X_train_numeric.to_numpy()
).astype("float32")

X_val_scaled = scaler.transform(
    X_val_numeric.to_numpy()
).astype("float32")

y_train_np = np.log1p(
    y_train.to_numpy()
).astype("float32")

y_val_np = np.log1p(
    y_val.to_numpy()
).astype("float32")

# %% [markdown]
# ### PyTorch Dataset and DataLoader

# %%
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
X_val_tensor = torch.tensor(X_val_scaled, dtype=torch.float32)

community_train_tensor = torch.tensor(
    community_train_idx,
    dtype=torch.long
)

community_val_tensor = torch.tensor(
    community_val_idx,
    dtype=torch.long
)

y_train_tensor = torch.tensor(y_train_np, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val_np, dtype=torch.float32)

train_weights_tensor = torch.tensor(
    train_weights_np,
    dtype=torch.float32
)

train_dataset = TensorDataset(
    X_train_tensor,
    community_train_tensor,
    y_train_tensor,
    train_weights_tensor,
)

val_dataset = TensorDataset(
    X_val_tensor,
    community_val_tensor,
    y_val_tensor,
)

# %% [markdown]
# **BATCH_SIZE** we start with a standard batch_size of 1024 as we have a lot of training data and a smaller batch_size would lead to too many updates in each epoche
#
# Possible, other used batch_sizes could be: 32, 64, 128, 256, 512, 1024, 2048

# %%
# Create the data loader
BATCH_SIZE = 1024

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# Test
X_batch, community_batch, y_batch, weight_batch = next(iter(train_loader))

print("Numerische Features:", X_batch.shape)
print("Community IDs:", community_batch.shape)
print("Target:", y_batch.shape)
print("Gewichte:", weight_batch.shape)
# Out:
# Numerische Features: torch.Size([1024, 22])
# Community IDs: torch.Size([1024])
# Target: torch.Size([1024, 1])
# Gewichte: torch.Size([1024])

# %% [markdown]
# ## Advanced Baseline v5

# %%
# model needs the number of features
input_dim = X_train_tensor.shape[1]

print("Input Features:", input_dim)
# Out:
# Input Features: 22

# %% [markdown]
# ### Model architecture

# %%
class TaxiDemandAdvancedNN(nn.Module):
    def __init__(
        self,
        numeric_input_dim,
        num_communities,
        embedding_dim=8,
    ):
        super().__init__()

        self.community_embedding = nn.Embedding(
            num_embeddings=num_communities,
            embedding_dim=embedding_dim,
            padding_idx=0,
        )

        combined_input_dim = numeric_input_dim + embedding_dim

        self.network = nn.Sequential(
            nn.Linear(combined_input_dim, 64),
            nn.ReLU(),

            nn.Linear(64, 32),
            nn.ReLU(),

            nn.Linear(32, 1),
        )

    def forward(self, x_numeric, community_idx):
        community_embedding = self.community_embedding(community_idx)

        combined = torch.cat(
            [x_numeric, community_embedding],
            dim=1,
        )

        return self.network(combined)

# %%
# initialise model
numeric_input_dim = X_train_tensor.shape[1]
embedding_dim = 8

model = TaxiDemandAdvancedNN(
    numeric_input_dim=numeric_input_dim,
    num_communities=num_communities,
    embedding_dim=embedding_dim,
)

# %%
# Test with one batch
X_batch, community_batch, y_batch, weight_batch = next(iter(train_loader))

y_pred = model(X_batch, community_batch)

print("Numeric input:", X_batch.shape)
print("Community input:", community_batch.shape)
print("Prediction:", y_pred.shape)
print("Target:", y_batch.shape)
# Out:
# Numeric input: torch.Size([1024, 22])
# Community input: torch.Size([1024])
# Prediction: torch.Size([1024, 1])
# Target: torch.Size([1024, 1])

# %% [markdown]
# There it important to check that the shape is the batch_size and the right dimension, i. e. number of features / target

# %%
device = get_torch_device()

print("Using device:", device)
model = model.to(device)
# Out:
# Using device: mps

# %% [markdown]
# ### Loss function and optimizer

# %% [markdown]
# As loss we start with MSELoss, which means that larger errors are larger penalized. And we use ADAM as optimizer with a learning rate of 0.001 as of now.
#
# Options for further models:
# - L1Loss(): more similar to MAE

# %%
criterion = nn.L1Loss(
    reduction="none",
)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-3,
    weight_decay=1e-5
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=5
)

# %% [markdown]
# ### Trainingsloop and Validation

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, device):
    model.train()
    
    total_loss = 0.0
    total_samples = 0
    
    for X_batch, community_batch, y_batch, weight_batch in train_loader:
        X_batch = X_batch.to(device)
        community_batch = community_batch.to(device)
        y_batch = y_batch.to(device)
        weight_batch = weight_batch.to(device)

        optimizer.zero_grad()

        y_pred = model(X_batch, community_batch)
        y_batch = y_batch.view_as(y_pred)

        individual_losses = criterion(y_pred, y_batch)

        loss = (
            individual_losses.reshape(-1)
            * weight_batch.reshape(-1)
        ).mean()

        loss.backward()
        optimizer.step()
        
        batch_size = X_batch.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size
    
    avg_loss = total_loss / total_samples
    return avg_loss

def evaluate(
    model,
    val_loader,
    criterion,
    device,
    high_demand_threshold=20,
):
    model.eval()

    total_loss = 0.0
    total_absolute_error = 0.0
    total_squared_error = 0.0
    total_samples = 0

    y_true_parts = []
    y_pred_parts = []

    with torch.no_grad():
        for X_batch, community_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            community_batch = community_batch.to(device)
            y_batch = y_batch.to(device)

            y_pred = model(X_batch, community_batch)
            y_batch = y_batch.view_as(y_pred)

            # L1Loss auf log1p-Skala
            loss = criterion(y_pred, y_batch).mean()

            # Rücktransformation auf trip_count-Skala
            y_pred_original = torch.expm1(y_pred)
            y_true_original = torch.expm1(y_batch)

            y_pred_original = torch.clamp(
                y_pred_original,
                min=0,
            )

            batch_size = X_batch.size(0)

            total_loss += loss.item() * batch_size
            total_absolute_error += torch.sum(
                torch.abs(y_pred_original - y_true_original)
            ).item()
            total_squared_error += torch.sum(
                (y_pred_original - y_true_original) ** 2
            ).item()
            total_samples += batch_size

            y_true_parts.append(
                y_true_original.cpu().numpy().reshape(-1)
            )
            y_pred_parts.append(
                y_pred_original.cpu().numpy().reshape(-1)
            )

    val_log_mae = total_loss / total_samples
    val_mae = total_absolute_error / total_samples
    val_rmse = (total_squared_error / total_samples) ** 0.5

    y_true = np.concatenate(y_true_parts)
    y_pred = np.concatenate(y_pred_parts)

    high_demand_mask = y_true > high_demand_threshold

    if high_demand_mask.any():
        high_demand_errors = np.abs(
            y_true[high_demand_mask]
            - y_pred[high_demand_mask]
        )

        high_demand_mae = high_demand_errors.mean()
        high_demand_median_ae = np.median(
            high_demand_errors
        )
    else:
        high_demand_mae = np.nan
        high_demand_median_ae = np.nan

    return (
        val_log_mae,
        val_mae,
        val_rmse,
        high_demand_mae,
        high_demand_median_ae,
    )

# %% [markdown]
# ### Start trainingsloop
#
# We use checkpoint to store the models parameter after each epoche

# %%
num_epochs = 200
patience = 15

best_selection_score = float("inf")
best_val_mae = float("inf")
best_high_demand_mae = float("inf")
best_epoch = 0

BASELINE_VAL_MAE = 2.2803 # from v5
BASELINE_HIGH_DEMAND_MAE = 20.396168 # from v5
GLOBAL_MAE_WEIGHT = 0.4
HIGH_DEMAND_MAE_WEIGHT = 0.6

epochs_without_improvement = 0

train_losses = []
val_losses = []
val_maes = []
val_rmses = []

for epoch in range(num_epochs):
    train_loss = train_one_epoch(
        model=model,
        train_loader=train_loader,
        criterion=criterion,
        optimizer=optimizer,
        device=device
    )

    (
        val_log_mae,
        val_mae,
        val_rmse,
        high_demand_mae,
        high_demand_median_ae,
    ) = evaluate(
        model=model,
        val_loader=val_loader,
        criterion=criterion,
        device=device,
        high_demand_threshold=20,
    )
    selection_score = (
        GLOBAL_MAE_WEIGHT
        * (val_mae / BASELINE_VAL_MAE)
        + HIGH_DEMAND_MAE_WEIGHT
        * (
            high_demand_mae
            / BASELINE_HIGH_DEMAND_MAE
        )
)
    

    scheduler.step(val_mae)

    train_losses.append(train_loss)
    val_losses.append(val_log_mae)
    val_maes.append(val_mae)
    val_rmses.append(val_rmse)

    if selection_score < best_selection_score:
        best_selection_score = selection_score
        best_val_mae = val_mae
        best_high_demand_mae = high_demand_mae
        best_epoch = epoch + 1
        epochs_without_improvement = 0

        checkpoint = {
            "epoch": epoch + 1,
            "numeric_input_dim": numeric_input_dim,
            "num_communities": num_communities,
            "embedding_dim": embedding_dim,
            "community_to_idx": community_to_idx,
            "numeric_feature_cols": numeric_feature_cols,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "val_log_mae": val_log_mae,
            "val_mae": val_mae,
            "val_rmse": val_rmse,
            "peak_mae": high_demand_mae,
            "peak_threshold": high_demand_median_ae,
            "selection_score": selection_score,
            "selection_weights": {
                "val_mae": GLOBAL_MAE_WEIGHT,
                "peak_mae": HIGH_DEMAND_MAE_WEIGHT,
            },
            "baseline_val_mae": BASELINE_VAL_MAE,
            "baseline_peak_mae": BASELINE_HIGH_DEMAND_MAE,
            "model_name": "advanced_baseline_v6_l1",
            "criterion": "weighted_l1_log_scale",
            "target_transform": "log1p",
            "selection_metric": "normalized_val_mae_and_peak_mae",
        }

        torch.save(
            checkpoint,
            Path(MODEL_PATH)
            / f"advanced_baseline_v6_NN_{MODEL_TAG}_best_model.pt",
        )
    else:
        epochs_without_improvement += 1

    current_lr = optimizer.param_groups[0]["lr"]

    print(
        f"Epoch {epoch+1:03d} | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Log MAE: {val_log_mae:.4f} | "
        f"Val MAE: {val_mae:.4f} | "
        f"Val RMSE: {val_rmse:.4f} | "
        f"High demand MAE: {high_demand_mae:.4f} | "
        f"Selection Score: {selection_score:.4f} | "
        f"LR: {current_lr:.6f} | "
        f"No Improvement: {epochs_without_improvement}/{patience}"
    )

    if epochs_without_improvement >= patience:
        print(
            f"Early stopping at epoch {epoch + 1}. "
            f"Best epoch: {best_epoch} | "
            f"Selection Score: {best_selection_score:.4f} | "
            f"Val MAE: {best_val_mae:.4f} | "
            f"Highdemand MAE: {best_high_demand_mae:.4f}"
        )
        break

history_df = pl.DataFrame({
    "epoch": range(1, len(train_losses) + 1),
    "train_loss": train_losses,
    "val_loss": val_losses,
    "val_mae": val_maes,
    "val_rmse": val_rmses,
})
HISTORY_PATH = Path(MODEL_PATH) / f"advanced_baseline_v6_NN_{MODEL_TAG}_training_history.parquet"
history_df.write_parquet(HISTORY_PATH)
print(f"Saved training history: {HISTORY_PATH}")

print(f"Best Epoch: {best_epoch}")
print(f"Best Selection Score: {best_selection_score:.4f}")
print(f"Best Val MAE: {best_val_mae:.4f}")
print(f"Highemand Peak MAE: {best_high_demand_mae:.4f}")
# Out:
# Epoch 001 | Train Loss: 0.6488 | Val Log MAE: 0.3308 | Val MAE: 2.8856 | Val RMSE: 11.7308 | High demand MAE: 27.9870 | Selection Score: 1.3295 | LR: 0.001000 | No Improvement: 0/15
# Epoch 002 | Train Loss: 0.4838 | Val Log MAE: 0.3202 | Val MAE: 2.7285 | Val RMSE: 10.5456 | High demand MAE: 25.7102 | Selection Score: 1.2349 | LR: 0.001000 | No Improvement: 0/15
# Epoch 003 | Train Loss: 0.4693 | Val Log MAE: 0.3111 | Val MAE: 2.6208 | Val RMSE: 10.7159 | High demand MAE: 25.4719 | Selection Score: 1.2090 | LR: 0.001000 | No Improvement: 0/15
# Epoch 004 | Train Loss: 0.4626 | Val Log MAE: 0.3092 | Val MAE: 2.5410 | Val RMSE: 10.1344 | High demand MAE: 23.8070 | Selection Score: 1.1461 | LR: 0.001000 | No Improvement: 0/15
# Epoch 005 | Train Loss: 0.4585 | Val Log MAE: 0.3073 | Val MAE: 2.5356 | Val RMSE: 10.4450 | High demand MAE: 24.1252 | Selection Score: 1.1545 | LR: 0.001000 | No Improvement: 1/15
# Epoch 006 | Train Loss: 0.4558 | Val Log MAE: 0.3108 | Val MAE: 2.7259 | Val RMSE: 10.9435 | High demand MAE: 26.0479 | Selection Score: 1.2444 | LR: 0.001000 | No Improvement: 2/15
# Epoch 007 | Train Loss: 0.4540 | Val Log MAE: 0.3067 | Val MAE: 2.4846 | Val RMSE: 9.6649 | High demand MAE: 22.9710 | Selection Score: 1.1116 | LR: 0.001000 | No Improvement: 0/15
# Epoch 008 | Train Loss: 0.4522 | Val Log MAE: 0.3039 | Val MAE: 2.4924 | Val RMSE: 10.0746 | High demand MAE: 23.7751 | Selection Score: 1.1366 | LR: 0.001000 | No Improvement: 1/15
# Epoch 009 | Train Loss: 0.4505 | Val Log MAE: 0.3060 | Val MAE: 2.4541 | Val RMSE: 9.4227 | High demand MAE: 22.4072 | Selection Score: 1.0896 | LR: 0.001000 | No Improvement: 0/15
# Epoch 010 | Train Loss: 0.4500 | Val Log MAE: 0.3031 | Val MAE: 2.4172 | Val RMSE: 9.4685 | High demand MAE: 22.2723 | Selection Score: 1.0792 | LR: 0.001000 | No Improvement: 0/15
# Epoch 011 | Train Loss: 0.4487 | Val Log MAE: 0.3031 | Val MAE: 2.4396 | Val RMSE: 9.7260 | High demand MAE: 22.7455 | Selection Score: 1.0971 | LR: 0.001000 | No Improvement: 1/15
# Epoch 012 | Train Loss: 0.4479 | Val Log MAE: 0.3019 | Val MAE: 2.4410 | Val RMSE: 9.7299 | High demand MAE: 22.9604 | Selection Score: 1.1036 | LR: 0.001000 | No Improvement: 2/15
# Epoch 013 | Train Loss: 0.4477 | Val Log MAE: 0.3041 | Val MAE: 2.4273 | Val RMSE: 9.6602 | High demand MAE: 22.1663 | Selection Score: 1.0779 | LR: 0.001000 | No Improvement: 0/15
# Epoch 014 | Train Loss: 0.4470 | Val Log MAE: 0.3034 | Val MAE: 2.4090 | Val RMSE: 9.3649 | High demand MAE: 22.1000 | Selection Score: 1.0727 | LR: 0.001000 | No Improvement: 0/15
# Epoch 015 | Train Loss: 0.4460 | Val Log MAE: 0.3015 | Val MAE: 2.4189 | Val RMSE: 9.4377 | High demand MAE: 22.5569 | Selection Score: 1.0879 | LR: 0.001000 | No Improvement: 1/15
# Epoch 016 | Train Loss: 0.4460 | Val Log MAE: 0.3074 | Val MAE: 2.5306 | Val RMSE: 9.7962 | High demand MAE: 23.3952 | Selection Score: 1.1321 | LR: 0.001000 | No Improvement: 2/15
# Epoch 017 | Train Loss: 0.4451 | Val Log MAE: 0.3078 | Val MAE: 2.8267 | Val RMSE: 11.5814 | High demand MAE: 27.5209 | Selection Score: 1.3054 | LR: 0.001000 | No Improvement: 3/15
# Epoch 018 | Train Loss: 0.4451 | Val Log MAE: 0.3025 | Val MAE: 2.4856 | Val RMSE: 9.6485 | High demand MAE: 23.1376 | Selection Score: 1.1167 | LR: 0.001000 | No Improvement: 4/15
# Epoch 019 | Train Loss: 0.4443 | Val Log MAE: 0.3042 | Val MAE: 2.5313 | Val RMSE: 9.8138 | High demand MAE: 23.4656 | Selection Score: 1.1343 | LR: 0.001000 | No Improvement: 5/15
# Epoch 020 | Train Loss: 0.4437 | Val Log MAE: 0.3005 | Val MAE: 2.4106 | Val RMSE: 9.4455 | High demand MAE: 22.5539 | Selection Score: 1.0863 | LR: 0.000500 | No Improvement: 6/15
# Epoch 021 | Train Loss: 0.4406 | Val Log MAE: 0.3032 | Val MAE: 2.4131 | Val RMSE: 9.2987 | High demand MAE: 22.0236 | Selection Score: 1.0712 | LR: 0.000500 | No Improvement: 0/15
# Epoch 022 | Train Loss: 0.4399 | Val Log MAE: 0.2993 | Val MAE: 2.3466 | Val RMSE: 9.1563 | High demand MAE: 21.6181 | Selection Score: 1.0476 | LR: 0.000500 | No Improvement: 0/15
# Epoch 023 | Train Loss: 0.4397 | Val Log MAE: 0.2991 | Val MAE: 2.3285 | Val RMSE: 9.0671 | High demand MAE: 21.2288 | Selection Score: 1.0330 | LR: 0.000500 | No Improvement: 0/15
# Epoch 024 | Train Loss: 0.4394 | Val Log MAE: 0.2993 | Val MAE: 2.3247 | Val RMSE: 9.0156 | High demand MAE: 21.1629 | Selection Score: 1.0303 | LR: 0.000500 | No Improvement: 0/15
# Epoch 025 | Train Loss: 0.4395 | Val Log MAE: 0.3006 | Val MAE: 2.3409 | Val RMSE: 9.0041 | High demand MAE: 21.1757 | Selection Score: 1.0336 | LR: 0.000500 | No Improvement: 1/15
# Epoch 026 | Train Loss: 0.4391 | Val Log MAE: 0.2990 | Val MAE: 2.3225 | Val RMSE: 8.9999 | High demand MAE: 21.0942 | Selection Score: 1.0279 | LR: 0.000500 | No Improvement: 0/15
# Epoch 027 | Train Loss: 0.4389 | Val Log MAE: 0.2998 | Val MAE: 2.3411 | Val RMSE: 9.0191 | High demand MAE: 21.3369 | Selection Score: 1.0383 | LR: 0.000500 | No Improvement: 1/15
# Epoch 028 | Train Loss: 0.4387 | Val Log MAE: 0.2979 | Val MAE: 2.3409 | Val RMSE: 9.2671 | High demand MAE: 21.7588 | Selection Score: 1.0507 | LR: 0.000500 | No Improvement: 2/15
# Epoch 029 | Train Loss: 0.4385 | Val Log MAE: 0.2994 | Val MAE: 2.3359 | Val RMSE: 9.0568 | High demand MAE: 21.4561 | Selection Score: 1.0409 | LR: 0.000500 | No Improvement: 3/15
# Epoch 030 | Train Loss: 0.4384 | Val Log MAE: 0.3011 | Val MAE: 2.3566 | Val RMSE: 9.0541 | High demand MAE: 21.2991 | Selection Score: 1.0399 | LR: 0.000500 | No Improvement: 4/15
# Epoch 031 | Train Loss: 0.4379 | Val Log MAE: 0.2987 | Val MAE: 2.3678 | Val RMSE: 9.2527 | High demand MAE: 21.9058 | Selection Score: 1.0598 | LR: 0.000500 | No Improvement: 5/15
# Epoch 032 | Train Loss: 0.4379 | Val Log MAE: 0.2992 | Val MAE: 2.3111 | Val RMSE: 8.9610 | High demand MAE: 20.9217 | Selection Score: 1.0209 | LR: 0.000500 | No Improvement: 0/15
# Epoch 033 | Train Loss: 0.4377 | Val Log MAE: 0.2974 | Val MAE: 2.3079 | Val RMSE: 9.0219 | High demand MAE: 21.2509 | Selection Score: 1.0300 | LR: 0.000500 | No Improvement: 1/15
# Epoch 034 | Train Loss: 0.4376 | Val Log MAE: 0.3022 | Val MAE: 2.4483 | Val RMSE: 9.8763 | High demand MAE: 22.4204 | Selection Score: 1.0890 | LR: 0.000500 | No Improvement: 2/15
# Epoch 035 | Train Loss: 0.4373 | Val Log MAE: 0.2976 | Val MAE: 2.3126 | Val RMSE: 9.0817 | High demand MAE: 21.1969 | Selection Score: 1.0292 | LR: 0.000500 | No Improvement: 3/15
# Epoch 036 | Train Loss: 0.4373 | Val Log MAE: 0.2975 | Val MAE: 2.3044 | Val RMSE: 9.0039 | High demand MAE: 21.1682 | Selection Score: 1.0269 | LR: 0.000500 | No Improvement: 4/15
# Epoch 037 | Train Loss: 0.4370 | Val Log MAE: 0.2978 | Val MAE: 2.3535 | Val RMSE: 9.3405 | High demand MAE: 22.0064 | Selection Score: 1.0602 | LR: 0.000500 | No Improvement: 5/15
# Epoch 038 | Train Loss: 0.4369 | Val Log MAE: 0.2988 | Val MAE: 2.3533 | Val RMSE: 9.1193 | High demand MAE: 21.4018 | Selection Score: 1.0424 | LR: 0.000500 | No Improvement: 6/15
# Epoch 039 | Train Loss: 0.4368 | Val Log MAE: 0.2984 | Val MAE: 2.3347 | Val RMSE: 9.0454 | High demand MAE: 21.3152 | Selection Score: 1.0366 | LR: 0.000500 | No Improvement: 7/15
# Epoch 040 | Train Loss: 0.4368 | Val Log MAE: 0.2986 | Val MAE: 2.3505 | Val RMSE: 9.2465 | High demand MAE: 21.7990 | Selection Score: 1.0536 | LR: 0.000500 | No Improvement: 8/15
# Epoch 041 | Train Loss: 0.4366 | Val Log MAE: 0.2977 | Val MAE: 2.3025 | Val RMSE: 9.1087 | High demand MAE: 20.9829 | Selection Score: 1.0212 | LR: 0.000500 | No Improvement: 9/15
# Epoch 042 | Train Loss: 0.4362 | Val Log MAE: 0.2974 | Val MAE: 2.2940 | Val RMSE: 8.9031 | High demand MAE: 20.9183 | Selection Score: 1.0178 | LR: 0.000500 | No Improvement: 0/15
# Epoch 043 | Train Loss: 0.4363 | Val Log MAE: 0.2974 | Val MAE: 2.2953 | Val RMSE: 8.8374 | High demand MAE: 20.8976 | Selection Score: 1.0174 | LR: 0.000500 | No Improvement: 0/15
# Epoch 044 | Train Loss: 0.4365 | Val Log MAE: 0.3006 | Val MAE: 2.3956 | Val RMSE: 9.1524 | High demand MAE: 21.7422 | Selection Score: 1.0598 | LR: 0.000500 | No Improvement: 1/15
# Epoch 045 | Train Loss: 0.4361 | Val Log MAE: 0.2979 | Val MAE: 2.3371 | Val RMSE: 9.1925 | High demand MAE: 21.5614 | Selection Score: 1.0442 | LR: 0.000500 | No Improvement: 2/15
# Epoch 046 | Train Loss: 0.4362 | Val Log MAE: 0.2971 | Val MAE: 2.2884 | Val RMSE: 8.8890 | High demand MAE: 20.8472 | Selection Score: 1.0147 | LR: 0.000500 | No Improvement: 0/15
# Epoch 047 | Train Loss: 0.4358 | Val Log MAE: 0.2979 | Val MAE: 2.5001 | Val RMSE: 10.1020 | High demand MAE: 24.3106 | Selection Score: 1.1537 | LR: 0.000500 | No Improvement: 1/15
# Epoch 048 | Train Loss: 0.4357 | Val Log MAE: 0.2971 | Val MAE: 2.2930 | Val RMSE: 8.8881 | High demand MAE: 20.9539 | Selection Score: 1.0186 | LR: 0.000500 | No Improvement: 2/15
# Epoch 049 | Train Loss: 0.4359 | Val Log MAE: 0.2991 | Val MAE: 2.3236 | Val RMSE: 9.0572 | High demand MAE: 20.8957 | Selection Score: 1.0223 | LR: 0.000500 | No Improvement: 3/15
# Epoch 050 | Train Loss: 0.4356 | Val Log MAE: 0.2969 | Val MAE: 2.2889 | Val RMSE: 8.9550 | High demand MAE: 20.8312 | Selection Score: 1.0143 | LR: 0.000500 | No Improvement: 0/15
# Epoch 051 | Train Loss: 0.4354 | Val Log MAE: 0.2990 | Val MAE: 2.3304 | Val RMSE: 8.9653 | High demand MAE: 21.0114 | Selection Score: 1.0269 | LR: 0.000500 | No Improvement: 1/15
# Epoch 052 | Train Loss: 0.4355 | Val Log MAE: 0.2993 | Val MAE: 2.3188 | Val RMSE: 8.9582 | High demand MAE: 20.9898 | Selection Score: 1.0242 | LR: 0.000250 | No Improvement: 2/15
# Epoch 053 | Train Loss: 0.4336 | Val Log MAE: 0.2963 | Val MAE: 2.2814 | Val RMSE: 8.8457 | High demand MAE: 20.8400 | Selection Score: 1.0132 | LR: 0.000250 | No Improvement: 0/15
# Epoch 054 | Train Loss: 0.4334 | Val Log MAE: 0.2984 | Val MAE: 2.3511 | Val RMSE: 9.1064 | High demand MAE: 21.4583 | Selection Score: 1.0437 | LR: 0.000250 | No Improvement: 1/15
# Epoch 055 | Train Loss: 0.4333 | Val Log MAE: 0.2966 | Val MAE: 2.2747 | Val RMSE: 8.7574 | High demand MAE: 20.6632 | Selection Score: 1.0069 | LR: 0.000250 | No Improvement: 0/15
# Epoch 056 | Train Loss: 0.4334 | Val Log MAE: 0.2972 | Val MAE: 2.2856 | Val RMSE: 8.8793 | High demand MAE: 20.8104 | Selection Score: 1.0131 | LR: 0.000250 | No Improvement: 1/15
# Epoch 057 | Train Loss: 0.4333 | Val Log MAE: 0.2967 | Val MAE: 2.2748 | Val RMSE: 8.8220 | High demand MAE: 20.5600 | Selection Score: 1.0039 | LR: 0.000250 | No Improvement: 0/15
# Epoch 058 | Train Loss: 0.4333 | Val Log MAE: 0.2977 | Val MAE: 2.3009 | Val RMSE: 8.8917 | High demand MAE: 20.7738 | Selection Score: 1.0147 | LR: 0.000250 | No Improvement: 1/15
# Epoch 059 | Train Loss: 0.4333 | Val Log MAE: 0.2961 | Val MAE: 2.2917 | Val RMSE: 8.9866 | High demand MAE: 21.1020 | Selection Score: 1.0228 | LR: 0.000250 | No Improvement: 2/15
# Epoch 060 | Train Loss: 0.4331 | Val Log MAE: 0.2981 | Val MAE: 2.2875 | Val RMSE: 8.7837 | High demand MAE: 20.5627 | Selection Score: 1.0062 | LR: 0.000250 | No Improvement: 3/15
# Epoch 061 | Train Loss: 0.4330 | Val Log MAE: 0.2972 | Val MAE: 2.2798 | Val RMSE: 8.8278 | High demand MAE: 20.5705 | Selection Score: 1.0050 | LR: 0.000125 | No Improvement: 4/15
# Epoch 062 | Train Loss: 0.4320 | Val Log MAE: 0.2969 | Val MAE: 2.2741 | Val RMSE: 8.8111 | High demand MAE: 20.5154 | Selection Score: 1.0024 | LR: 0.000125 | No Improvement: 0/15
# Epoch 063 | Train Loss: 0.4320 | Val Log MAE: 0.2964 | Val MAE: 2.2709 | Val RMSE: 8.8051 | High demand MAE: 20.5585 | Selection Score: 1.0031 | LR: 0.000125 | No Improvement: 1/15
# Epoch 064 | Train Loss: 0.4319 | Val Log MAE: 0.2979 | Val MAE: 2.3096 | Val RMSE: 8.9163 | High demand MAE: 20.9038 | Selection Score: 1.0201 | LR: 0.000125 | No Improvement: 2/15
# Epoch 065 | Train Loss: 0.4319 | Val Log MAE: 0.2970 | Val MAE: 2.2704 | Val RMSE: 8.7859 | High demand MAE: 20.4674 | Selection Score: 1.0004 | LR: 0.000125 | No Improvement: 0/15
# Epoch 066 | Train Loss: 0.4319 | Val Log MAE: 0.2962 | Val MAE: 2.2737 | Val RMSE: 8.8221 | High demand MAE: 20.6192 | Selection Score: 1.0054 | LR: 0.000125 | No Improvement: 1/15
# Epoch 067 | Train Loss: 0.4318 | Val Log MAE: 0.2968 | Val MAE: 2.2741 | Val RMSE: 8.8151 | High demand MAE: 20.5696 | Selection Score: 1.0040 | LR: 0.000125 | No Improvement: 2/15
# Epoch 068 | Train Loss: 0.4318 | Val Log MAE: 0.2964 | Val MAE: 2.2657 | Val RMSE: 8.7753 | High demand MAE: 20.4805 | Selection Score: 0.9999 | LR: 0.000125 | No Improvement: 0/15
# Epoch 069 | Train Loss: 0.4318 | Val Log MAE: 0.2976 | Val MAE: 2.2810 | Val RMSE: 8.8037 | High demand MAE: 20.5692 | Selection Score: 1.0052 | LR: 0.000125 | No Improvement: 1/15
# Epoch 070 | Train Loss: 0.4318 | Val Log MAE: 0.2963 | Val MAE: 2.2688 | Val RMSE: 8.8110 | High demand MAE: 20.5792 | Selection Score: 1.0034 | LR: 0.000125 | No Improvement: 2/15
# Epoch 071 | Train Loss: 0.4317 | Val Log MAE: 0.2968 | Val MAE: 2.2705 | Val RMSE: 8.8118 | High demand MAE: 20.5139 | Selection Score: 1.0017 | LR: 0.000125 | No Improvement: 3/15
# Epoch 072 | Train Loss: 0.4317 | Val Log MAE: 0.2967 | Val MAE: 2.2669 | Val RMSE: 8.7976 | High demand MAE: 20.4907 | Selection Score: 1.0004 | LR: 0.000125 | No Improvement: 4/15
# Epoch 073 | Train Loss: 0.4317 | Val Log MAE: 0.2967 | Val MAE: 2.2732 | Val RMSE: 8.7777 | High demand MAE: 20.5300 | Selection Score: 1.0027 | LR: 0.000125 | No Improvement: 5/15
# Epoch 074 | Train Loss: 0.4317 | Val Log MAE: 0.2966 | Val MAE: 2.2692 | Val RMSE: 8.7693 | High demand MAE: 20.5245 | Selection Score: 1.0018 | LR: 0.000063 | No Improvement: 6/15
# Epoch 075 | Train Loss: 0.4311 | Val Log MAE: 0.2964 | Val MAE: 2.2697 | Val RMSE: 8.7745 | High demand MAE: 20.5287 | Selection Score: 1.0020 | LR: 0.000063 | No Improvement: 7/15
# Epoch 076 | Train Loss: 0.4311 | Val Log MAE: 0.2962 | Val MAE: 2.2643 | Val RMSE: 8.7680 | High demand MAE: 20.4649 | Selection Score: 0.9992 | LR: 0.000063 | No Improvement: 0/15
# Epoch 077 | Train Loss: 0.4311 | Val Log MAE: 0.2965 | Val MAE: 2.2677 | Val RMSE: 8.7985 | High demand MAE: 20.4826 | Selection Score: 1.0003 | LR: 0.000063 | No Improvement: 1/15
# Epoch 078 | Train Loss: 0.4311 | Val Log MAE: 0.2965 | Val MAE: 2.2619 | Val RMSE: 8.7422 | High demand MAE: 20.3985 | Selection Score: 0.9968 | LR: 0.000063 | No Improvement: 0/15
# Epoch 079 | Train Loss: 0.4311 | Val Log MAE: 0.2966 | Val MAE: 2.2666 | Val RMSE: 8.7894 | High demand MAE: 20.4669 | Selection Score: 0.9997 | LR: 0.000063 | No Improvement: 1/15
# Epoch 080 | Train Loss: 0.4310 | Val Log MAE: 0.2965 | Val MAE: 2.2678 | Val RMSE: 8.8063 | High demand MAE: 20.5074 | Selection Score: 1.0011 | LR: 0.000063 | No Improvement: 2/15
# Epoch 081 | Train Loss: 0.4310 | Val Log MAE: 0.2965 | Val MAE: 2.2643 | Val RMSE: 8.7662 | High demand MAE: 20.4200 | Selection Score: 0.9979 | LR: 0.000063 | No Improvement: 3/15
# Epoch 082 | Train Loss: 0.4310 | Val Log MAE: 0.2968 | Val MAE: 2.2770 | Val RMSE: 8.8436 | High demand MAE: 20.5589 | Selection Score: 1.0042 | LR: 0.000063 | No Improvement: 4/15
# Epoch 083 | Train Loss: 0.4310 | Val Log MAE: 0.2967 | Val MAE: 2.2703 | Val RMSE: 8.8102 | High demand MAE: 20.4825 | Selection Score: 1.0008 | LR: 0.000063 | No Improvement: 5/15
# Epoch 084 | Train Loss: 0.4310 | Val Log MAE: 0.2963 | Val MAE: 2.2624 | Val RMSE: 8.7488 | High demand MAE: 20.4462 | Selection Score: 0.9983 | LR: 0.000031 | No Improvement: 6/15
# Epoch 085 | Train Loss: 0.4307 | Val Log MAE: 0.2964 | Val MAE: 2.2625 | Val RMSE: 8.7566 | High demand MAE: 20.4361 | Selection Score: 0.9981 | LR: 0.000031 | No Improvement: 7/15
# Epoch 086 | Train Loss: 0.4307 | Val Log MAE: 0.2967 | Val MAE: 2.2647 | Val RMSE: 8.7607 | High demand MAE: 20.3973 | Selection Score: 0.9973 | LR: 0.000031 | No Improvement: 8/15
# Epoch 087 | Train Loss: 0.4307 | Val Log MAE: 0.2962 | Val MAE: 2.2595 | Val RMSE: 8.7579 | High demand MAE: 20.4300 | Selection Score: 0.9973 | LR: 0.000031 | No Improvement: 9/15
# Epoch 088 | Train Loss: 0.4307 | Val Log MAE: 0.2963 | Val MAE: 2.2600 | Val RMSE: 8.7442 | High demand MAE: 20.4236 | Selection Score: 0.9973 | LR: 0.000031 | No Improvement: 10/15
# Epoch 089 | Train Loss: 0.4307 | Val Log MAE: 0.2967 | Val MAE: 2.2642 | Val RMSE: 8.7526 | High demand MAE: 20.3791 | Selection Score: 0.9967 | LR: 0.000031 | No Improvement: 0/15
# Epoch 090 | Train Loss: 0.4307 | Val Log MAE: 0.2962 | Val MAE: 2.2598 | Val RMSE: 8.7456 | High demand MAE: 20.4216 | Selection Score: 0.9972 | LR: 0.000031 | No Improvement: 1/15
# Epoch 091 | Train Loss: 0.4307 | Val Log MAE: 0.2965 | Val MAE: 2.2630 | Val RMSE: 8.7484 | High demand MAE: 20.4067 | Selection Score: 0.9973 | LR: 0.000031 | No Improvement: 2/15
# Epoch 092 | Train Loss: 0.4306 | Val Log MAE: 0.2965 | Val MAE: 2.2641 | Val RMSE: 8.7636 | High demand MAE: 20.4418 | Selection Score: 0.9985 | LR: 0.000031 | No Improvement: 3/15
# Epoch 093 | Train Loss: 0.4306 | Val Log MAE: 0.2964 | Val MAE: 2.2612 | Val RMSE: 8.7518 | High demand MAE: 20.4165 | Selection Score: 0.9973 | LR: 0.000016 | No Improvement: 4/15
# Epoch 094 | Train Loss: 0.4305 | Val Log MAE: 0.2964 | Val MAE: 2.2609 | Val RMSE: 8.7445 | High demand MAE: 20.3977 | Selection Score: 0.9966 | LR: 0.000016 | No Improvement: 0/15
# Epoch 095 | Train Loss: 0.4305 | Val Log MAE: 0.2965 | Val MAE: 2.2630 | Val RMSE: 8.7499 | High demand MAE: 20.4091 | Selection Score: 0.9973 | LR: 0.000016 | No Improvement: 1/15
# Epoch 096 | Train Loss: 0.4305 | Val Log MAE: 0.2966 | Val MAE: 2.2630 | Val RMSE: 8.7467 | High demand MAE: 20.3919 | Selection Score: 0.9968 | LR: 0.000016 | No Improvement: 2/15
# Epoch 097 | Train Loss: 0.4305 | Val Log MAE: 0.2965 | Val MAE: 2.2613 | Val RMSE: 8.7413 | High demand MAE: 20.3902 | Selection Score: 0.9965 | LR: 0.000016 | No Improvement: 0/15
# Epoch 098 | Train Loss: 0.4305 | Val Log MAE: 0.2965 | Val MAE: 2.2612 | Val RMSE: 8.7410 | High demand MAE: 20.3896 | Selection Score: 0.9965 | LR: 0.000016 | No Improvement: 0/15
# Epoch 099 | Train Loss: 0.4304 | Val Log MAE: 0.2961 | Val MAE: 2.2596 | Val RMSE: 8.7563 | High demand MAE: 20.4532 | Selection Score: 0.9981 | LR: 0.000008 | No Improvement: 1/15
# Epoch 100 | Train Loss: 0.4304 | Val Log MAE: 0.2963 | Val MAE: 2.2590 | Val RMSE: 8.7509 | High demand MAE: 20.4049 | Selection Score: 0.9965 | LR: 0.000008 | No Improvement: 2/15
# Epoch 101 | Train Loss: 0.4304 | Val Log MAE: 0.2963 | Val MAE: 2.2593 | Val RMSE: 8.7423 | High demand MAE: 20.3845 | Selection Score: 0.9960 | LR: 0.000008 | No Improvement: 0/15
# Epoch 102 | Train Loss: 0.4304 | Val Log MAE: 0.2963 | Val MAE: 2.2601 | Val RMSE: 8.7424 | High demand MAE: 20.3845 | Selection Score: 0.9961 | LR: 0.000008 | No Improvement: 1/15
# Epoch 103 | Train Loss: 0.4304 | Val Log MAE: 0.2964 | Val MAE: 2.2602 | Val RMSE: 8.7491 | High demand MAE: 20.3864 | Selection Score: 0.9962 | LR: 0.000008 | No Improvement: 2/15
# Epoch 104 | Train Loss: 0.4304 | Val Log MAE: 0.2962 | Val MAE: 2.2588 | Val RMSE: 8.7497 | High demand MAE: 20.4037 | Selection Score: 0.9964 | LR: 0.000008 | No Improvement: 3/15
# Epoch 105 | Train Loss: 0.4304 | Val Log MAE: 0.2964 | Val MAE: 2.2604 | Val RMSE: 8.7460 | High demand MAE: 20.3887 | Selection Score: 0.9963 | LR: 0.000008 | No Improvement: 4/15
# Epoch 106 | Train Loss: 0.4304 | Val Log MAE: 0.2961 | Val MAE: 2.2584 | Val RMSE: 8.7549 | High demand MAE: 20.4225 | Selection Score: 0.9969 | LR: 0.000008 | No Improvement: 5/15
# Epoch 107 | Train Loss: 0.4304 | Val Log MAE: 0.2964 | Val MAE: 2.2600 | Val RMSE: 8.7451 | High demand MAE: 20.3849 | Selection Score: 0.9961 | LR: 0.000008 | No Improvement: 6/15
# Epoch 108 | Train Loss: 0.4304 | Val Log MAE: 0.2964 | Val MAE: 2.2601 | Val RMSE: 8.7463 | High demand MAE: 20.3919 | Selection Score: 0.9963 | LR: 0.000008 | No Improvement: 7/15
# Epoch 109 | Train Loss: 0.4303 | Val Log MAE: 0.2964 | Val MAE: 2.2603 | Val RMSE: 8.7432 | High demand MAE: 20.3859 | Selection Score: 0.9962 | LR: 0.000008 | No Improvement: 8/15
# Epoch 110 | Train Loss: 0.4304 | Val Log MAE: 0.2965 | Val MAE: 2.2604 | Val RMSE: 8.7488 | High demand MAE: 20.3792 | Selection Score: 0.9960 | LR: 0.000008 | No Improvement: 9/15
# Epoch 111 | Train Loss: 0.4304 | Val Log MAE: 0.2963 | Val MAE: 2.2596 | Val RMSE: 8.7487 | High demand MAE: 20.3890 | Selection Score: 0.9962 | LR: 0.000008 | No Improvement: 10/15
# Epoch 112 | Train Loss: 0.4303 | Val Log MAE: 0.2965 | Val MAE: 2.2608 | Val RMSE: 8.7426 | High demand MAE: 20.3821 | Selection Score: 0.9962 | LR: 0.000004 | No Improvement: 11/15
# Epoch 113 | Train Loss: 0.4303 | Val Log MAE: 0.2963 | Val MAE: 2.2599 | Val RMSE: 8.7479 | High demand MAE: 20.3929 | Selection Score: 0.9963 | LR: 0.000004 | No Improvement: 12/15
# Epoch 114 | Train Loss: 0.4303 | Val Log MAE: 0.2963 | Val MAE: 2.2588 | Val RMSE: 8.7489 | High demand MAE: 20.3949 | Selection Score: 0.9962 | LR: 0.000004 | No Improvement: 13/15
# Epoch 115 | Train Loss: 0.4303 | Val Log MAE: 0.2964 | Val MAE: 2.2603 | Val RMSE: 8.7450 | High demand MAE: 20.3791 | Selection Score: 0.9960 | LR: 0.000004 | No Improvement: 14/15
# Epoch 116 | Train Loss: 0.4303 | Val Log MAE: 0.2963 | Val MAE: 2.2595 | Val RMSE: 8.7495 | High demand MAE: 20.3948 | Selection Score: 0.9963 | LR: 0.000004 | No Improvement: 15/15
# Early stopping at epoch 116. Best epoch: 101 | Selection Score: 0.9960 | Val MAE: 2.2593 | Highdemand MAE: 20.3845
# Best Epoch: 101
# Best Selection Score: 0.9960
# Best Val MAE: 2.2593
# Highemand Peak MAE: 20.3845

# %% [markdown]
# ### Load best model after training

# %%
device = get_torch_device()

model, checkpoint = load_model_from_checkpoint(
    model_class=TaxiDemandAdvancedNN,
    checkpoint_path=(
        Path(MODEL_PATH)
        / f"advanced_baseline_v6_NN_{MODEL_TAG}_best_model.pt"
    ),
    device=device,
)

# %% [markdown]
# ## Analyse model performance

# %%
val_eval_df = collect_predictions(
    model,
    val_loader,
    device=device,
    embedding_input=True,
)

val_metrics_df = compute_regression_metrics(val_eval_df)
print(val_metrics_df)

figure, bucket_eval_df = plot_regression_diagnostics(
    val_eval_df
)

plt.show()
print(bucket_eval_df)
# Out:
# shape: (16, 2)
# ┌────────────────┬───────────┐
# │ metric         ┆ value     │
# │ ---            ┆ ---       │
# │ str            ┆ f64       │
# ╞════════════════╪═══════════╡
# │ n_samples      ┆ 236011.0  │
# │ mae            ┆ 2.259323  │
# │ mse            ┆ 76.427834 │
# │ rmse           ┆ 8.742301  │
# │ r2             ┆ 0.937642  │
# │ …              ┆ …         │
# │ nonzero_rmse   ┆ 11.53393  │
# │ peak_threshold ┆ 26.000002 │
# │ peak_share     ┆ 0.056497  │
# │ peak_mae       ┆ 22.945831 │
# │ peak_rmse      ┆ 35.255013 │
# └────────────────┴───────────┘
# shape: (7, 5)
# ┌───────────────┬────────┬───────────┬────────────┬──────────────┐
# │ demand_bucket ┆ n_rows ┆ mae       ┆ avg_y_true ┆ bucket_order │
# │ ---           ┆ ---    ┆ ---       ┆ ---        ┆ ---          │
# │ str           ┆ u32    ┆ f32       ┆ f32        ┆ i64          │
# ╞═══════════════╪════════╪═══════════╪════════════╪══════════════╡
# │ 0             ┆ 103526 ┆ 0.333868  ┆ 0.0        ┆ 0            │
# │ 1             ┆ 46118  ┆ 0.733841  ┆ 1.0        ┆ 1            │
# │ 2-3           ┆ 37565  ┆ 1.204315  ┆ 2.360495   ┆ 2            │
# │ 4-5           ┆ 13616  ┆ 2.004997  ┆ 4.397106   ┆ 3            │
# │ 6-10          ┆ 11039  ┆ 2.804963  ┆ 7.191593   ┆ 4            │
# │ 11-20         ┆ 8344   ┆ 4.695219  ┆ 13.549617  ┆ 5            │
# │ >20           ┆ 15803  ┆ 20.384533 ┆ 102.870659 ┆ 6            │
# └───────────────┴────────┴───────────┴────────────┴──────────────┘
