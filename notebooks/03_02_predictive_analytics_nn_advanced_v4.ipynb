# %% [markdown]
# # Predictive Analytics: Neural Network - Advanced Baseline v4
#
# Note: theoretically we would need to either encode the spatial feature (i. e. community area) or train a separate model for each spatial unit. Otherwise the feature "community_area" is a continuous numeric feature!
#
# => based on advanced baseline v3, focus here is to improve performance for high demand buckets
#
# Model v3 is underpredicting the demand -> we introduce a weighted loss

# %%
import polars as pl
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from pathlib import Path
import math
import matplotlib.pyplot as plt

from run_config import MODELS_DIR, PATHS

from helper_functions import (
    get_torch_device,
    load_model_from_checkpoint,
    collect_predictions,
    compute_regression_metrics,
    plot_regression_diagnostics,
)

# %% [markdown]
# ## Preparations

# %%
# Dataset loop configuration
DATASET_CONFIGS = (
    {"spatial_unit": "hexagon", "spatial_col": "h3_cell", "time_unit": "1h"},
    {"spatial_unit": "census_tracts", "spatial_col": "census_tract", "time_unit": "1h"},
    {"spatial_unit": "community_areas", "spatial_col": "community_area", "time_unit": "1h"},
    {"spatial_unit": "hexagon", "spatial_col": "h3_cell", "time_unit": "2h"},
    {"spatial_unit": "census_tracts", "spatial_col": "census_tract", "time_unit": "2h"},
    {"spatial_unit": "community_areas", "spatial_col": "community_area", "time_unit": "2h"},
    {"spatial_unit": "hexagon", "spatial_col": "h3_cell", "time_unit": "4h"},
    {"spatial_unit": "census_tracts", "spatial_col": "census_tract", "time_unit": "4h"},
    {"spatial_unit": "community_areas", "spatial_col": "community_area", "time_unit": "4h"},
)
MODEL_PATH = MODELS_DIR
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# Target and feature selection
TARGET_COL = "trip_count"
EXCLUDE_COLS = [
    TARGET_COL,
    "datetime_hour",      # real timestamp would lead to much leakage
    "_split_bucket",      # only used for splitting
    "month", # cyclic feature is used instead
    "weekday", # cyclic feature is used instead
    "hour", # cyclic feature is used instead
    # all other taxi data columns must be excluded to prevent leakage
    "trip_seconds_sum",
    "trip_seconds_mean",
    "trip_seconds_min",
    "trip_seconds_max",
    "trip_miles_sum",
    "trip_miles_mean",
    "trip_miles_min",
    "trip_miles_max",
    "fare_sum",
    "fare_mean",
    "fare_min",
    "fare_max",
    "tips_sum",
    "tips_mean",
    "tips_min",
    "tips_max",
    "tolls_sum",
    "tolls_mean",
    "tolls_min",
    "tolls_max",
    "extras_sum",
    "extras_mean",
    "extras_min",
    "extras_max",
    "trip_total_sum",
    "trip_total_mean",
    "trip_total_min",
    "trip_total_max",
    "most_common_payment_type",
]

# %% [markdown]
# ### Load the data and select features and target

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# Impotant, check datatype of features and target. Everything should be numerical. We already applied encoding to categorical features (e. g. cloud coverage), therefore all features are numerical.

# %%
def make_sample_weights(y_original):
    y = np.asarray(y_original).reshape(-1)

    weights = np.ones_like(y, dtype=np.float32)

    weights[(y > 0) & (y <= 2)] = 1.2
    weights[(y > 2) & (y <= 10)] = 1.5
    weights[(y > 10) & (y <= 20)] = 3.0
    weights[y > 20] = 5.0

    return weights

train_weights_np = make_sample_weights(y_train)

# %% [markdown]
# ### Scale the train data
#
# Important, the scaler is only fitted on X_train to prevent data leakage

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# ### PyTorch Dataset and DataLoader

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# **BATCH_SIZE** we start with a standard batch_size of 1024 as we have a lot of training data and a smaller batch_size would lead to too many updates in each epoche
#
# Possible, other used batch_sizes could be: 32, 64, 128, 256, 512, 1024, 2048

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# ## Advanced Baseline v4

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# ### Model architecture

# %%
class TaxiDemandAdvancedNN(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        
        self.network = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            
            nn.Linear(64, 32),
            nn.ReLU(),
            
            nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.network(x)

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# There it important to check that the shape is the batch_size and the right dimension, i. e. number of features / target

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# ### Loss function and optimizer

# %% [markdown]
# As loss we start with MSELoss, which means that larger errors are larger penalized. And we use ADAM as optimizer with a learning rate of 0.001 as of now.
#
# Options for further models:
# - L1Loss(): more similar to MAE

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# ### Trainingsloop and Validation

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, device):
    model.train()

    total_loss = 0.0
    total_samples = 0

    for X_batch, y_batch, weight_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        weight_batch = weight_batch.to(device)

        optimizer.zero_grad()

        y_pred = model(X_batch)
        y_batch = y_batch.view_as(y_pred)

        individual_losses = criterion(y_pred, y_batch)

        loss = (
            individual_losses.reshape(-1)
            * weight_batch.reshape(-1)
        ).mean()

        loss.backward()
        optimizer.step()

        batch_size = X_batch.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size

    return total_loss / total_samples

def evaluate(model, val_loader, criterion, device):
    model.eval()
    
    total_loss = 0.0
    total_absolute_error = 0.0
    total_squared_error = 0.0
    total_samples = 0
    
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            y_pred = model(X_batch)

            y_batch = y_batch.view_as(y_pred)

            loss = criterion(y_pred, y_batch).mean()
            
            # back transformation
            y_pred_original = torch.expm1(y_pred)
            y_true_original = torch.expm1(y_batch)

            y_pred_original = torch.clamp(y_pred_original, min=0)
            
            batch_size = X_batch.size(0)
            
            total_loss += loss.item() * batch_size

            # MAE/RMSE on original scaled data
            total_absolute_error += torch.sum(
                torch.abs(y_pred_original - y_true_original)
            ).item()

            total_squared_error += torch.sum(
                (y_pred_original - y_true_original) ** 2
            ).item()

            total_samples += batch_size
    
    avg_loss = total_loss / total_samples
    mae = total_absolute_error / total_samples
    rmse = (total_squared_error / total_samples) ** 0.5
    
    return avg_loss, mae, rmse

# %% [markdown]
# ### Start trainingsloop
#
# We use checkpoint to store the models parameter after each epoche

# %%
def train_dataset_v4(dataset_config):
    SPATIAL_UNIT = dataset_config["spatial_unit"]
    SPATIAL_COL = dataset_config["spatial_col"]
    TIME_UNIT = dataset_config["time_unit"]
    DATASET_STEM = f"GOLD_{TIME_UNIT.upper()}_DEMAND_{SPATIAL_UNIT.upper()}"
    MODEL_TAG = f"{SPATIAL_UNIT}_{TIME_UNIT}"
    TRAINING_DATA_PATH = PATHS.train_test_dir / f"{DATASET_STEM}_TRAIN.parquet"
    VAL_DATA_PATH = PATHS.train_test_dir / f"{DATASET_STEM}_VAL.parquet"

    print(f"\n=== Training v4: {MODEL_TAG} ===")
    print(f"Train: {TRAINING_DATA_PATH}")
    print(f"Validation: {VAL_DATA_PATH}")
    # Load the tranining data
    train_df = pl.scan_parquet(TRAINING_DATA_PATH)
    val_df = pl.scan_parquet(VAL_DATA_PATH)

    # Create X and Y data
    feature_cols = [
        col for col in train_df.collect_schema().names()
        if col not in EXCLUDE_COLS
    ]

    X_train = train_df.select(feature_cols).collect()
    y_train = train_df.select(TARGET_COL).collect()

    X_val = val_df.select(feature_cols).collect()
    y_val = val_df.select(TARGET_COL).collect()

    print("Features: ", X_train.schema)
    print("Target: ", y_train.schema)
    if X_train.height == 0 or X_val.height == 0:
        raise ValueError(f"Empty train or validation split for {MODEL_TAG}")

    # Encode the spatial identifier consistently for train and validation.
    spatial_values = sorted(
        X_train.select(pl.col(SPATIAL_COL).cast(pl.String)).to_series().unique().to_list()
    )
    spatial_to_idx = {value: index for index, value in enumerate(spatial_values)}
    X_train = X_train.with_columns(
        pl.col(SPATIAL_COL)
        .cast(pl.String)
        .replace_strict(spatial_to_idx, default=-1)
        .cast(pl.Float32)
        .alias(SPATIAL_COL)
    )
    X_val = X_val.with_columns(
        pl.col(SPATIAL_COL)
        .cast(pl.String)
        .replace_strict(spatial_to_idx, default=-1)
        .cast(pl.Float32)
        .alias(SPATIAL_COL)
    )

    # transform to numpy as it works best with scaler
    X_train_np_original = X_train.to_numpy()
    X_val_np_original = X_val.to_numpy()

    # fit scaler
    scaler = StandardScaler()

    X_train_scaled = scaler.fit_transform(X_train_np_original) # fit only called on train
    X_val_scaled = scaler.transform(X_val_np_original) # only transformed, not fitted!

    # prepare target and features
    # log1p transformation
    y_train_np = np.log1p(y_train.to_numpy()).astype("float32")
    y_val_np = np.log1p(y_val.to_numpy()).astype("float32")
    X_train_scaled = X_train_scaled.astype("float32")
    X_val_scaled = X_val_scaled.astype("float32")

    print(X_train_scaled.shape)
    print(y_train_np.shape)

    print(X_val_scaled.shape)
    print(y_val_np.shape)
    # Convert to pytorch tensor
    X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train_np, dtype=torch.float32)

    X_val_tensor = torch.tensor(X_val_scaled, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val_np, dtype=torch.float32)

    train_weights_tensor = torch.tensor(
        train_weights_np,
        dtype=torch.float32
    )

    print(X_train_tensor.shape)
    print(y_train_tensor.shape)

    print(X_val_tensor.shape)
    print(y_val_tensor.shape)

    # Tensor dataset
    train_dataset = TensorDataset(
        X_train_tensor,
        y_train_tensor,
        train_weights_tensor
    )
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    # Create the data loader
    BATCH_SIZE = 1024

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    # Test
    X_batch, y_batch, weight_batch = next(iter(train_loader))

    print("Features:", X_batch.shape)
    print("Target:", y_batch.shape)
    print("Weights:", weight_batch.shape)
    # model needs the number of features
    input_dim = X_train_tensor.shape[1]

    print("Input Features:", input_dim)
    # initialise model
    model = TaxiDemandAdvancedNN(
        input_dim=input_dim
    )
    print(model)
    # Test with one batch
    X_batch, y_batch, weight_batch = next(iter(train_loader))

    y_pred = model(X_batch)

    print("Input batch:", X_batch.shape)
    print("Prediction batch:", y_pred.shape)
    print("Target batch:", y_batch.shape)
    if torch.backends.mps.is_available():
        device = torch.device("mps")
    elif torch.cuda.is_available():
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")

    print("Using device:", device)
    model = model.to(device)
    criterion = nn.SmoothL1Loss(beta=0.5, reduction="none") # due to weighted loss

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=1e-3,
        weight_decay=1e-5
    )

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        factor=0.5,
        patience=5
    )
    num_epochs = 200
    patience = 15

    best_val_mae = float("inf")
    best_epoch = 0
    epochs_without_improvement = 0

    train_losses = []
    val_losses = []
    val_maes = []
    val_rmses = []

    for epoch in range(num_epochs):
        train_loss = train_one_epoch(
            model=model,
            train_loader=train_loader,
            criterion=criterion,
            optimizer=optimizer,
            device=device
        )

        val_loss, val_mae, val_rmse = evaluate(
            model=model,
            val_loader=val_loader,
            criterion=criterion,
            device=device
        )

        scheduler.step(val_mae)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_maes.append(val_mae)
        val_rmses.append(val_rmse)

        if val_mae < best_val_mae:
            best_val_mae = val_mae
            best_epoch = epoch + 1
            epochs_without_improvement = 0

            checkpoint = {
                "epoch": epoch + 1,
                "input_dim": input_dim,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "scheduler_state_dict": scheduler.state_dict(),
                "val_loss": val_loss,
                "val_mae": val_mae,
                "val_rmse": val_rmse,
                "model_name": "advanced_baseline_v4",
                "target_transform": "log1p",
                "selection_metric": "val_mae",
            }

            torch.save(
                checkpoint,
                MODEL_PATH / f"advanced_baseline_v4_NN_{MODEL_TAG}_best_model.pt"
            )

            print(f"New best model saved | Val MAE: {best_val_mae:.4f}")

        else:
            epochs_without_improvement += 1

        current_lr = optimizer.param_groups[0]["lr"]

        print(
            f"Epoch {epoch+1:03d} | "
            f"Train Loss: {train_loss:.4f} | "
            f"Val Loss: {val_loss:.4f} | "
            f"Val MAE: {val_mae:.4f} | "
            f"Val RMSE: {val_rmse:.4f} | "
            f"LR: {current_lr:.6f} | "
            f"No Improvement: {epochs_without_improvement}/{patience}"
        )

        if epochs_without_improvement >= patience:
            print(
                f"Early stopping at epoch {epoch+1}. "
                f"Best epoch was {best_epoch} with Val MAE: {best_val_mae:.4f}"
            )
            break

    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val MAE: {best_val_mae:.4f}")
    history_df = pl.DataFrame({
        "epoch": range(1, len(train_losses) + 1),
        "train_loss": train_losses,
        "val_loss": val_losses,
        "val_mae": val_maes,
        "val_rmse": val_rmses,
    })
    history_path = MODEL_PATH / f"advanced_baseline_v4_NN_{MODEL_TAG}_training_history.parquet"
    history_df.write_parquet(history_path)
    print(f"Saved training history: {history_path}")

    device = get_torch_device()

    model, checkpoint = load_model_from_checkpoint(
        model_class=TaxiDemandAdvancedNN,
        checkpoint_path=(
            Path(MODEL_PATH)
            / f"advanced_baseline_v4_NN_{MODEL_TAG}_best_model.pt"
        ),
        device=device,
    )
    val_eval_df = collect_predictions(
        model,
        val_loader,
        device=device,
        embedding_input=False,
    )

    val_metrics_df = compute_regression_metrics(val_eval_df)
    print(val_metrics_df)

    figure, bucket_eval_df = plot_regression_diagnostics(
        val_eval_df
    )

    plt.show()
    print(bucket_eval_df)
    return {
        "model_tag": MODEL_TAG,
        "model_path": MODEL_PATH / f"advanced_baseline_v4_NN_{MODEL_TAG}_best_model.pt",
        "history_path": history_path,
        "metrics": val_metrics_df,
        "bucket_metrics": bucket_eval_df,
    }


training_results = {}
for dataset_config in DATASET_CONFIGS:
    result = train_dataset_v4(dataset_config)
    training_results[result["model_tag"]] = result

print("Completed models:", list(training_results))
# Out:
# New best model saved | Val MAE: 3.9731
# Epoch 001 | Train Loss: 0.5927 | Val Loss: 0.2555 | Val MAE: 3.9731 | Val RMSE: 15.0600 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 3.0220
# Epoch 002 | Train Loss: 0.3180 | Val Loss: 0.1956 | Val MAE: 3.0220 | Val RMSE: 12.3455 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.7166
# Epoch 003 | Train Loss: 0.2745 | Val Loss: 0.1861 | Val MAE: 2.7166 | Val RMSE: 10.5277 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.6651
# Epoch 004 | Train Loss: 0.2615 | Val Loss: 0.1832 | Val MAE: 2.6651 | Val RMSE: 10.3315 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.5775
# Epoch 005 | Train Loss: 0.2530 | Val Loss: 0.1787 | Val MAE: 2.5775 | Val RMSE: 9.7937 | LR: 0.001000 | No Improvement: 0/15
# Epoch 006 | Train Loss: 0.2485 | Val Loss: 0.1780 | Val MAE: 2.6764 | Val RMSE: 11.3290 | LR: 0.001000 | No Improvement: 1/15
# Epoch 007 | Train Loss: 0.2451 | Val Loss: 0.1753 | Val MAE: 2.5815 | Val RMSE: 10.0497 | LR: 0.001000 | No Improvement: 2/15
# New best model saved | Val MAE: 2.5255
# Epoch 008 | Train Loss: 0.2427 | Val Loss: 0.1717 | Val MAE: 2.5255 | Val RMSE: 9.8488 | LR: 0.001000 | No Improvement: 0/15
# Epoch 009 | Train Loss: 0.2407 | Val Loss: 0.1707 | Val MAE: 2.5861 | Val RMSE: 10.2789 | LR: 0.001000 | No Improvement: 1/15
# New best model saved | Val MAE: 2.4043
# Epoch 010 | Train Loss: 0.2384 | Val Loss: 0.1679 | Val MAE: 2.4043 | Val RMSE: 9.3524 | LR: 0.001000 | No Improvement: 0/15
# Epoch 011 | Train Loss: 0.2368 | Val Loss: 0.1680 | Val MAE: 2.4412 | Val RMSE: 9.4501 | LR: 0.001000 | No Improvement: 1/15
# Epoch 012 | Train Loss: 0.2351 | Val Loss: 0.1664 | Val MAE: 2.4109 | Val RMSE: 9.4621 | LR: 0.001000 | No Improvement: 2/15
# Epoch 013 | Train Loss: 0.2340 | Val Loss: 0.1682 | Val MAE: 2.4397 | Val RMSE: 9.3245 | LR: 0.001000 | No Improvement: 3/15
# Epoch 014 | Train Loss: 0.2331 | Val Loss: 0.1661 | Val MAE: 2.4497 | Val RMSE: 9.5033 | LR: 0.001000 | No Improvement: 4/15
# Epoch 015 | Train Loss: 0.2317 | Val Loss: 0.1647 | Val MAE: 2.4756 | Val RMSE: 9.7870 | LR: 0.001000 | No Improvement: 5/15
# New best model saved | Val MAE: 2.3896
# Epoch 016 | Train Loss: 0.2312 | Val Loss: 0.1690 | Val MAE: 2.3896 | Val RMSE: 9.0736 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.3764
# Epoch 017 | Train Loss: 0.2304 | Val Loss: 0.1646 | Val MAE: 2.3764 | Val RMSE: 9.1881 | LR: 0.001000 | No Improvement: 0/15
# Epoch 018 | Train Loss: 0.2297 | Val Loss: 0.1634 | Val MAE: 2.4015 | Val RMSE: 9.3781 | LR: 0.001000 | No Improvement: 1/15
# Epoch 019 | Train Loss: 0.2291 | Val Loss: 0.1650 | Val MAE: 2.5442 | Val RMSE: 10.1498 | LR: 0.001000 | No Improvement: 2/15
# New best model saved | Val MAE: 2.3453
# Epoch 020 | Train Loss: 0.2287 | Val Loss: 0.1636 | Val MAE: 2.3453 | Val RMSE: 9.0898 | LR: 0.001000 | No Improvement: 0/15
# Epoch 021 | Train Loss: 0.2278 | Val Loss: 0.1643 | Val MAE: 2.4215 | Val RMSE: 9.3284 | LR: 0.001000 | No Improvement: 1/15
# Epoch 022 | Train Loss: 0.2277 | Val Loss: 0.1611 | Val MAE: 2.4184 | Val RMSE: 9.5744 | LR: 0.001000 | No Improvement: 2/15
# Epoch 023 | Train Loss: 0.2271 | Val Loss: 0.1608 | Val MAE: 2.3725 | Val RMSE: 9.5342 | LR: 0.001000 | No Improvement: 3/15
# Epoch 024 | Train Loss: 0.2266 | Val Loss: 0.1631 | Val MAE: 2.3845 | Val RMSE: 9.2055 | LR: 0.001000 | No Improvement: 4/15
# Epoch 025 | Train Loss: 0.2261 | Val Loss: 0.1622 | Val MAE: 2.3611 | Val RMSE: 9.0601 | LR: 0.001000 | No Improvement: 5/15
# Epoch 026 | Train Loss: 0.2253 | Val Loss: 0.1625 | Val MAE: 2.3608 | Val RMSE: 9.0738 | LR: 0.000500 | No Improvement: 6/15
# New best model saved | Val MAE: 2.2755
# Epoch 027 | Train Loss: 0.2224 | Val Loss: 0.1603 | Val MAE: 2.2755 | Val RMSE: 8.6042 | LR: 0.000500 | No Improvement: 0/15
# Epoch 028 | Train Loss: 0.2220 | Val Loss: 0.1633 | Val MAE: 2.3465 | Val RMSE: 9.0821 | LR: 0.000500 | No Improvement: 1/15
# Epoch 029 | Train Loss: 0.2219 | Val Loss: 0.1604 | Val MAE: 2.2871 | Val RMSE: 8.7608 | LR: 0.000500 | No Improvement: 2/15
# Epoch 030 | Train Loss: 0.2216 | Val Loss: 0.1626 | Val MAE: 2.3630 | Val RMSE: 8.9938 | LR: 0.000500 | No Improvement: 3/15
# Epoch 031 | Train Loss: 0.2215 | Val Loss: 0.1604 | Val MAE: 2.3389 | Val RMSE: 9.0191 | LR: 0.000500 | No Improvement: 4/15
# New best model saved | Val MAE: 2.2754
# Epoch 032 | Train Loss: 0.2213 | Val Loss: 0.1591 | Val MAE: 2.2754 | Val RMSE: 8.7428 | LR: 0.000500 | No Improvement: 0/15
# Epoch 033 | Train Loss: 0.2213 | Val Loss: 0.1602 | Val MAE: 2.2774 | Val RMSE: 8.6677 | LR: 0.000250 | No Improvement: 1/15
# New best model saved | Val MAE: 2.2565
# Epoch 034 | Train Loss: 0.2195 | Val Loss: 0.1588 | Val MAE: 2.2565 | Val RMSE: 8.5675 | LR: 0.000250 | No Improvement: 0/15
# Epoch 035 | Train Loss: 0.2193 | Val Loss: 0.1580 | Val MAE: 2.2566 | Val RMSE: 8.6438 | LR: 0.000250 | No Improvement: 1/15
# Epoch 036 | Train Loss: 0.2192 | Val Loss: 0.1600 | Val MAE: 2.2705 | Val RMSE: 8.6124 | LR: 0.000250 | No Improvement: 2/15
# New best model saved | Val MAE: 2.2548
# Epoch 037 | Train Loss: 0.2191 | Val Loss: 0.1579 | Val MAE: 2.2548 | Val RMSE: 8.6872 | LR: 0.000250 | No Improvement: 0/15
# Epoch 038 | Train Loss: 0.2191 | Val Loss: 0.1599 | Val MAE: 2.2611 | Val RMSE: 8.5530 | LR: 0.000250 | No Improvement: 1/15
# New best model saved | Val MAE: 2.2458
# Epoch 039 | Train Loss: 0.2190 | Val Loss: 0.1579 | Val MAE: 2.2458 | Val RMSE: 8.5362 | LR: 0.000250 | No Improvement: 0/15
# Epoch 040 | Train Loss: 0.2189 | Val Loss: 0.1605 | Val MAE: 2.2995 | Val RMSE: 8.6617 | LR: 0.000250 | No Improvement: 1/15
# Epoch 041 | Train Loss: 0.2188 | Val Loss: 0.1594 | Val MAE: 2.2499 | Val RMSE: 8.5272 | LR: 0.000250 | No Improvement: 2/15
# Epoch 042 | Train Loss: 0.2187 | Val Loss: 0.1591 | Val MAE: 2.2578 | Val RMSE: 8.5023 | LR: 0.000250 | No Improvement: 3/15
# Epoch 043 | Train Loss: 0.2187 | Val Loss: 0.1592 | Val MAE: 2.2616 | Val RMSE: 8.5323 | LR: 0.000250 | No Improvement: 4/15
# Epoch 044 | Train Loss: 0.2186 | Val Loss: 0.1593 | Val MAE: 2.2790 | Val RMSE: 8.7212 | LR: 0.000250 | No Improvement: 5/15
# Epoch 045 | Train Loss: 0.2185 | Val Loss: 0.1597 | Val MAE: 2.2705 | Val RMSE: 8.5351 | LR: 0.000125 | No Improvement: 6/15
# Epoch 046 | Train Loss: 0.2176 | Val Loss: 0.1583 | Val MAE: 2.2745 | Val RMSE: 8.7513 | LR: 0.000125 | No Improvement: 7/15
# New best model saved | Val MAE: 2.2299
# Epoch 047 | Train Loss: 0.2175 | Val Loss: 0.1581 | Val MAE: 2.2299 | Val RMSE: 8.4491 | LR: 0.000125 | No Improvement: 0/15
# Epoch 048 | Train Loss: 0.2175 | Val Loss: 0.1582 | Val MAE: 2.2361 | Val RMSE: 8.4523 | LR: 0.000125 | No Improvement: 1/15
# Epoch 049 | Train Loss: 0.2174 | Val Loss: 0.1597 | Val MAE: 2.2457 | Val RMSE: 8.4669 | LR: 0.000125 | No Improvement: 2/15
# Epoch 050 | Train Loss: 0.2174 | Val Loss: 0.1590 | Val MAE: 2.2439 | Val RMSE: 8.4424 | LR: 0.000125 | No Improvement: 3/15
# Epoch 051 | Train Loss: 0.2173 | Val Loss: 0.1596 | Val MAE: 2.2532 | Val RMSE: 8.5007 | LR: 0.000125 | No Improvement: 4/15
# New best model saved | Val MAE: 2.2282
# Epoch 052 | Train Loss: 0.2173 | Val Loss: 0.1584 | Val MAE: 2.2282 | Val RMSE: 8.3824 | LR: 0.000125 | No Improvement: 0/15
# Epoch 053 | Train Loss: 0.2173 | Val Loss: 0.1587 | Val MAE: 2.2293 | Val RMSE: 8.3617 | LR: 0.000125 | No Improvement: 1/15
# New best model saved | Val MAE: 2.2176
# Epoch 054 | Train Loss: 0.2172 | Val Loss: 0.1578 | Val MAE: 2.2176 | Val RMSE: 8.3624 | LR: 0.000125 | No Improvement: 0/15
# Epoch 055 | Train Loss: 0.2172 | Val Loss: 0.1587 | Val MAE: 2.2530 | Val RMSE: 8.5934 | LR: 0.000125 | No Improvement: 1/15
# Epoch 056 | Train Loss: 0.2171 | Val Loss: 0.1578 | Val MAE: 2.2391 | Val RMSE: 8.5310 | LR: 0.000125 | No Improvement: 2/15
# Epoch 057 | Train Loss: 0.2171 | Val Loss: 0.1580 | Val MAE: 2.2511 | Val RMSE: 8.5975 | LR: 0.000125 | No Improvement: 3/15
# Epoch 058 | Train Loss: 0.2171 | Val Loss: 0.1582 | Val MAE: 2.2238 | Val RMSE: 8.3702 | LR: 0.000125 | No Improvement: 4/15
# Epoch 059 | Train Loss: 0.2170 | Val Loss: 0.1582 | Val MAE: 2.2310 | Val RMSE: 8.4195 | LR: 0.000125 | No Improvement: 5/15
# Epoch 060 | Train Loss: 0.2170 | Val Loss: 0.1583 | Val MAE: 2.2276 | Val RMSE: 8.3853 | LR: 0.000063 | No Improvement: 6/15
# Epoch 061 | Train Loss: 0.2165 | Val Loss: 0.1583 | Val MAE: 2.2227 | Val RMSE: 8.3709 | LR: 0.000063 | No Improvement: 7/15
# New best model saved | Val MAE: 2.2152
# Epoch 062 | Train Loss: 0.2165 | Val Loss: 0.1580 | Val MAE: 2.2152 | Val RMSE: 8.3409 | LR: 0.000063 | No Improvement: 0/15
# Epoch 063 | Train Loss: 0.2165 | Val Loss: 0.1585 | Val MAE: 2.2237 | Val RMSE: 8.3586 | LR: 0.000063 | No Improvement: 1/15
# Epoch 064 | Train Loss: 0.2164 | Val Loss: 0.1576 | Val MAE: 2.2220 | Val RMSE: 8.4033 | LR: 0.000063 | No Improvement: 2/15
# Epoch 065 | Train Loss: 0.2164 | Val Loss: 0.1578 | Val MAE: 2.2304 | Val RMSE: 8.4507 | LR: 0.000063 | No Improvement: 3/15
# Epoch 066 | Train Loss: 0.2164 | Val Loss: 0.1585 | Val MAE: 2.2482 | Val RMSE: 8.5015 | LR: 0.000063 | No Improvement: 4/15
# Epoch 067 | Train Loss: 0.2163 | Val Loss: 0.1575 | Val MAE: 2.2195 | Val RMSE: 8.3946 | LR: 0.000063 | No Improvement: 5/15
# Epoch 068 | Train Loss: 0.2163 | Val Loss: 0.1579 | Val MAE: 2.2191 | Val RMSE: 8.3499 | LR: 0.000031 | No Improvement: 6/15
# New best model saved | Val MAE: 2.2102
# Epoch 069 | Train Loss: 0.2161 | Val Loss: 0.1579 | Val MAE: 2.2102 | Val RMSE: 8.3157 | LR: 0.000031 | No Improvement: 0/15
# Epoch 070 | Train Loss: 0.2161 | Val Loss: 0.1574 | Val MAE: 2.2128 | Val RMSE: 8.3702 | LR: 0.000031 | No Improvement: 1/15
# Epoch 071 | Train Loss: 0.2161 | Val Loss: 0.1572 | Val MAE: 2.2143 | Val RMSE: 8.3860 | LR: 0.000031 | No Improvement: 2/15
# New best model saved | Val MAE: 2.2094
# Epoch 072 | Train Loss: 0.2161 | Val Loss: 0.1576 | Val MAE: 2.2094 | Val RMSE: 8.3251 | LR: 0.000031 | No Improvement: 0/15
# Epoch 073 | Train Loss: 0.2160 | Val Loss: 0.1572 | Val MAE: 2.2138 | Val RMSE: 8.3743 | LR: 0.000031 | No Improvement: 1/15
# Epoch 074 | Train Loss: 0.2160 | Val Loss: 0.1579 | Val MAE: 2.2134 | Val RMSE: 8.3403 | LR: 0.000031 | No Improvement: 2/15
# Epoch 075 | Train Loss: 0.2160 | Val Loss: 0.1575 | Val MAE: 2.2134 | Val RMSE: 8.3651 | LR: 0.000031 | No Improvement: 3/15
# Epoch 076 | Train Loss: 0.2160 | Val Loss: 0.1577 | Val MAE: 2.2107 | Val RMSE: 8.3337 | LR: 0.000031 | No Improvement: 4/15
# New best model saved | Val MAE: 2.2083
# Epoch 077 | Train Loss: 0.2160 | Val Loss: 0.1575 | Val MAE: 2.2083 | Val RMSE: 8.3437 | LR: 0.000031 | No Improvement: 0/15
# Epoch 078 | Train Loss: 0.2160 | Val Loss: 0.1586 | Val MAE: 2.2246 | Val RMSE: 8.3410 | LR: 0.000031 | No Improvement: 1/15
# Epoch 079 | Train Loss: 0.2160 | Val Loss: 0.1573 | Val MAE: 2.2141 | Val RMSE: 8.3841 | LR: 0.000031 | No Improvement: 2/15
# Epoch 080 | Train Loss: 0.2160 | Val Loss: 0.1578 | Val MAE: 2.2143 | Val RMSE: 8.3323 | LR: 0.000031 | No Improvement: 3/15
# Epoch 081 | Train Loss: 0.2160 | Val Loss: 0.1573 | Val MAE: 2.2134 | Val RMSE: 8.3792 | LR: 0.000031 | No Improvement: 4/15
# Epoch 082 | Train Loss: 0.2160 | Val Loss: 0.1575 | Val MAE: 2.2109 | Val RMSE: 8.3595 | LR: 0.000031 | No Improvement: 5/15
# Epoch 083 | Train Loss: 0.2160 | Val Loss: 0.1580 | Val MAE: 2.2152 | Val RMSE: 8.3174 | LR: 0.000016 | No Improvement: 6/15
# Epoch 084 | Train Loss: 0.2158 | Val Loss: 0.1577 | Val MAE: 2.2092 | Val RMSE: 8.3223 | LR: 0.000016 | No Improvement: 7/15
# Epoch 085 | Train Loss: 0.2158 | Val Loss: 0.1574 | Val MAE: 2.2156 | Val RMSE: 8.3906 | LR: 0.000016 | No Improvement: 8/15
# Epoch 086 | Train Loss: 0.2158 | Val Loss: 0.1574 | Val MAE: 2.2087 | Val RMSE: 8.3416 | LR: 0.000016 | No Improvement: 9/15
# Epoch 087 | Train Loss: 0.2158 | Val Loss: 0.1578 | Val MAE: 2.2148 | Val RMSE: 8.3465 | LR: 0.000016 | No Improvement: 10/15
# Epoch 088 | Train Loss: 0.2158 | Val Loss: 0.1574 | Val MAE: 2.2136 | Val RMSE: 8.3864 | LR: 0.000016 | No Improvement: 11/15
# Epoch 089 | Train Loss: 0.2158 | Val Loss: 0.1574 | Val MAE: 2.2120 | Val RMSE: 8.3710 | LR: 0.000008 | No Improvement: 12/15
# Epoch 090 | Train Loss: 0.2157 | Val Loss: 0.1577 | Val MAE: 2.2089 | Val RMSE: 8.3256 | LR: 0.000008 | No Improvement: 13/15
# Epoch 091 | Train Loss: 0.2157 | Val Loss: 0.1578 | Val MAE: 2.2110 | Val RMSE: 8.3283 | LR: 0.000008 | No Improvement: 14/15
# Epoch 092 | Train Loss: 0.2157 | Val Loss: 0.1576 | Val MAE: 2.2101 | Val RMSE: 8.3376 | LR: 0.000008 | No Improvement: 15/15
# Early stopping at epoch 92. Best epoch was 77 with Val MAE: 2.2083
# Best Epoch: 77
# Best Val MAE: 2.2083

# %% [markdown]
# ### Load best model after training

# %%
# Executed inside train_dataset_v4 for every dataset configuration.

# %% [markdown]
# ## Analyse model performance

# %%
# Executed inside train_dataset_v4 for every dataset configuration.
