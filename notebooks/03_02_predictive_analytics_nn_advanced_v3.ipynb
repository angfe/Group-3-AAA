# %% [markdown]
# # Predictive Analytics: Neural Network - Advanced Baseline v3
#
# Note: theoretically we would need to either encode the spatial feature (i. e. community area) or train a separate model for each spatial unit. Otherwise the feature "community_area" is a continuous numeric feature!
#
# => based on advanced baseline v2
#
# Advanced Baseline v3
# = v2 Architektur
# + log1p Target
# + AdamW mit schwachem Weight Decay
# + SmoothL1Loss / Huber Loss
# + Learning Rate Scheduler
# + Early Stopping nach val_mae
#
# => This model has the best performance sofar, however it performs especially well for low demand and bad for higher demand. This should be adjusted within v4.

# %%
import polars as pl
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from pathlib import Path
import math
import matplotlib.pyplot as plt

from run_config import MODELS_DIR, PATHS

from helper_functions import (
    get_torch_device,
    load_model_from_checkpoint,
    collect_predictions,
    compute_regression_metrics,
    plot_regression_diagnostics,
)

# %% [markdown]
# ## Preparations

# %%
# Dataset loop configuration
DATASET_CONFIGS = (
    {"spatial_unit": "hexagon", "spatial_col": "h3_cell", "time_unit": "1h"},
    {"spatial_unit": "census_tracts", "spatial_col": "census_tract", "time_unit": "1h"},
    {"spatial_unit": "community_areas", "spatial_col": "community_area", "time_unit": "1h"},
    {"spatial_unit": "hexagon", "spatial_col": "h3_cell", "time_unit": "2h"},
    {"spatial_unit": "census_tracts", "spatial_col": "census_tract", "time_unit": "2h"},
    {"spatial_unit": "community_areas", "spatial_col": "community_area", "time_unit": "2h"},
    {"spatial_unit": "hexagon", "spatial_col": "h3_cell", "time_unit": "4h"},
    {"spatial_unit": "census_tracts", "spatial_col": "census_tract", "time_unit": "4h"},
    {"spatial_unit": "community_areas", "spatial_col": "community_area", "time_unit": "4h"},
)
MODEL_PATH = MODELS_DIR
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# Target and feature selection
TARGET_COL = "trip_count"
EXCLUDE_COLS = [
    TARGET_COL,
    "datetime_hour",      # real timestamp would lead to much leakage
    "_split_bucket",      # only used for splitting
    "month", # cyclic feature is used instead
    "weekday", # cyclic feature is used instead
    "hour", # cyclic feature is used instead
    # all other taxi data columns must be excluded to prevent leakage
    "trip_seconds_sum",
    "trip_seconds_mean",
    "trip_seconds_min",
    "trip_seconds_max",
    "trip_miles_sum",
    "trip_miles_mean",
    "trip_miles_min",
    "trip_miles_max",
    "fare_sum",
    "fare_mean",
    "fare_min",
    "fare_max",
    "tips_sum",
    "tips_mean",
    "tips_min",
    "tips_max",
    "tolls_sum",
    "tolls_mean",
    "tolls_min",
    "tolls_max",
    "extras_sum",
    "extras_mean",
    "extras_min",
    "extras_max",
    "trip_total_sum",
    "trip_total_mean",
    "trip_total_min",
    "trip_total_max",
    "most_common_payment_type",
]

# %% [markdown]
# ### Load the data and select features and target

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# Impotant, check datatype of features and target. Everything should be numerical. We already applied encoding to categorical features (e. g. cloud coverage), therefore all features are numerical.

# %% [markdown]
# ### Scale the train data
#
# Important, the scaler is only fitted on X_train to prevent data leakage

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# ### PyTorch Dataset and DataLoader

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# **BATCH_SIZE** we start with a standard batch_size of 1024 as we have a lot of training data and a smaller batch_size would lead to too many updates in each epoche
#
# Possible, other used batch_sizes could be: 32, 64, 128, 256, 512, 1024, 2048

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# ## Advanced Baseline v3

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# ### Model architecture

# %%
class TaxiDemandAdvancedNN(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        
        self.network = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            
            nn.Linear(64, 32),
            nn.ReLU(),
            
            nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.network(x)

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# There it important to check that the shape is the batch_size and the right dimension, i. e. number of features / target

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# ### Loss function and optimizer

# %% [markdown]
# As loss we start with MSELoss, which means that larger errors are larger penalized. And we use ADAM as optimizer with a learning rate of 0.001 as of now.
#
# Options for further models:
# - L1Loss(): more similar to MAE

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# ### Trainingsloop and Validation

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, device):
    model.train()
    
    total_loss = 0.0
    total_samples = 0
    
    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        
        # 1. Alte Gradienten löschen
        optimizer.zero_grad()
        
        # 2. Forward Pass
        y_pred = model(X_batch)
        
        # 3. Loss berechnen
        loss = criterion(y_pred, y_batch)
        
        # 4. Backpropagation
        loss.backward()
        
        # 5. Gewichte updaten
        optimizer.step()
        
        batch_size = X_batch.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size
    
    avg_loss = total_loss / total_samples
    return avg_loss

def evaluate(model, val_loader, criterion, device):
    model.eval()
    
    total_loss = 0.0
    total_absolute_error = 0.0
    total_squared_error = 0.0
    total_samples = 0
    
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            
            y_pred = model(X_batch)

            y_batch = y_batch.view_as(y_pred)

            loss = criterion(y_pred, y_batch)
            
            # back transformation
            y_pred_original = torch.expm1(y_pred)
            y_true_original = torch.expm1(y_batch)

            y_pred_original = torch.clamp(y_pred_original, min=0)
            
            batch_size = X_batch.size(0)
            
            total_loss += loss.item() * batch_size

            # MAE/RMSE on original scaled data
            total_absolute_error += torch.sum(
                torch.abs(y_pred_original - y_true_original)
            ).item()

            total_squared_error += torch.sum(
                (y_pred_original - y_true_original) ** 2
            ).item()

            total_samples += batch_size
    
    avg_loss = total_loss / total_samples
    mae = total_absolute_error / total_samples
    rmse = (total_squared_error / total_samples) ** 0.5
    
    return avg_loss, mae, rmse

# %% [markdown]
# ### Start trainingsloop
#
# We use checkpoint to store the models parameter after each epoche

# %%
def train_dataset_v3(dataset_config):
    SPATIAL_UNIT = dataset_config["spatial_unit"]
    SPATIAL_COL = dataset_config["spatial_col"]
    TIME_UNIT = dataset_config["time_unit"]
    DATASET_STEM = f"GOLD_{TIME_UNIT.upper()}_DEMAND_{SPATIAL_UNIT.upper()}"
    MODEL_TAG = f"{SPATIAL_UNIT}_{TIME_UNIT}"
    TRAINING_DATA_PATH = PATHS.train_test_dir / f"{DATASET_STEM}_TRAIN.parquet"
    VAL_DATA_PATH = PATHS.train_test_dir / f"{DATASET_STEM}_VAL.parquet"

    print(f"\n=== Training v3: {MODEL_TAG} ===")
    print(f"Train: {TRAINING_DATA_PATH}")
    print(f"Validation: {VAL_DATA_PATH}")
    # Load the tranining data
    train_df = pl.scan_parquet(TRAINING_DATA_PATH)
    val_df = pl.scan_parquet(VAL_DATA_PATH)

    # Create X and Y data
    feature_cols = [
        col for col in train_df.collect_schema().names()
        if col not in EXCLUDE_COLS
    ]

    X_train = train_df.select(feature_cols).collect()
    y_train = train_df.select(TARGET_COL).collect()

    X_val = val_df.select(feature_cols).collect()
    y_val = val_df.select(TARGET_COL).collect()

    print("Features: ", X_train.schema)
    print("Target: ", y_train.schema)
    if X_train.height == 0 or X_val.height == 0:
        raise ValueError(f"Empty train or validation split for {MODEL_TAG}")

    # Encode the spatial identifier consistently for train and validation.
    spatial_values = sorted(
        X_train.select(pl.col(SPATIAL_COL).cast(pl.String)).to_series().unique().to_list()
    )
    spatial_to_idx = {value: index for index, value in enumerate(spatial_values)}
    X_train = X_train.with_columns(
        pl.col(SPATIAL_COL)
        .cast(pl.String)
        .replace_strict(spatial_to_idx, default=-1)
        .cast(pl.Float32)
        .alias(SPATIAL_COL)
    )
    X_val = X_val.with_columns(
        pl.col(SPATIAL_COL)
        .cast(pl.String)
        .replace_strict(spatial_to_idx, default=-1)
        .cast(pl.Float32)
        .alias(SPATIAL_COL)
    )

    # transform to numpy as it works best with scaler
    X_train_np = X_train.to_numpy()
    X_val_np = X_val.to_numpy()

    # fit scaler
    scaler = StandardScaler()

    X_train_scaled = scaler.fit_transform(X_train_np) # fit only called on train
    X_val_scaled = scaler.transform(X_val_np) # only transformed, not fitted!

    # prepare target and features
    # log1p transformation
    y_train_np = np.log1p(y_train.to_numpy()).astype("float32")
    y_val_np = np.log1p(y_val.to_numpy()).astype("float32")
    X_train_scaled = X_train_scaled.astype("float32")
    X_val_scaled = X_val_scaled.astype("float32")

    print(X_train_scaled.shape)
    print(y_train_np.shape)

    print(X_val_scaled.shape)
    print(y_val_np.shape)
    # Convert to pytorch tensor
    X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train_np, dtype=torch.float32)

    X_val_tensor = torch.tensor(X_val_scaled, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val_np, dtype=torch.float32)

    print(X_train_tensor.shape)
    print(y_train_tensor.shape)

    print(X_val_tensor.shape)
    print(y_val_tensor.shape)

    # Tensor dataset
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    # Create the data loader
    BATCH_SIZE = 1024

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False
    )

    # Test
    X_batch, y_batch = next(iter(train_loader))

    print(X_batch.shape)
    print(y_batch.shape)
    # model needs the number of features
    input_dim = X_train_tensor.shape[1]

    print("Input Features:", input_dim)
    # initialise model
    model = TaxiDemandAdvancedNN(
        input_dim=input_dim
    )
    print(model)
    # Test with one batch
    X_batch, y_batch = next(iter(train_loader))

    y_pred = model(X_batch)

    print("Input batch:", X_batch.shape)
    print("Prediction batch:", y_pred.shape)
    print("Target batch:", y_batch.shape)
    if torch.backends.mps.is_available():
        device = torch.device("mps")
    elif torch.cuda.is_available():
        device = torch.device("cuda")
    else:
        device = torch.device("cpu")

    print("Using device:", device)
    model = model.to(device)
    criterion = nn.SmoothL1Loss(beta=0.5)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=1e-3,
        weight_decay=1e-5
    )

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        factor=0.5,
        patience=5
    )
    num_epochs = 200
    patience = 15

    best_val_mae = float("inf")
    best_epoch = 0
    epochs_without_improvement = 0

    train_losses = []
    val_losses = []
    val_maes = []
    val_rmses = []

    for epoch in range(num_epochs):
        train_loss = train_one_epoch(
            model=model,
            train_loader=train_loader,
            criterion=criterion,
            optimizer=optimizer,
            device=device
        )

        val_loss, val_mae, val_rmse = evaluate(
            model=model,
            val_loader=val_loader,
            criterion=criterion,
            device=device
        )

        scheduler.step(val_mae)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_maes.append(val_mae)
        val_rmses.append(val_rmse)

        if val_mae < best_val_mae:
            best_val_mae = val_mae
            best_epoch = epoch + 1
            epochs_without_improvement = 0

            checkpoint = {
                "epoch": epoch + 1,
                "input_dim": input_dim,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "scheduler_state_dict": scheduler.state_dict(),
                "val_loss": val_loss,
                "val_mae": val_mae,
                "val_rmse": val_rmse,
                "model_name": "advanced_baseline_v3",
                "target_transform": "log1p",
                "selection_metric": "val_mae",
            }

            torch.save(
                checkpoint,
                MODEL_PATH / f"advanced_baseline_v3_NN_{MODEL_TAG}_best_model.pt"
            )

            print(f"New best model saved | Val MAE: {best_val_mae:.4f}")

        else:
            epochs_without_improvement += 1

        current_lr = optimizer.param_groups[0]["lr"]

        print(
            f"Epoch {epoch+1:03d} | "
            f"Train Loss: {train_loss:.4f} | "
            f"Val Loss: {val_loss:.4f} | "
            f"Val MAE: {val_mae:.4f} | "
            f"Val RMSE: {val_rmse:.4f} | "
            f"LR: {current_lr:.6f} | "
            f"No Improvement: {epochs_without_improvement}/{patience}"
        )

        if epochs_without_improvement >= patience:
            print(
                f"Early stopping at epoch {epoch+1}. "
                f"Best epoch was {best_epoch} with Val MAE: {best_val_mae:.4f}"
            )
            break

    print(f"Best Epoch: {best_epoch}")
    print(f"Best Val MAE: {best_val_mae:.4f}")
    history_df = pl.DataFrame({
        "epoch": range(1, len(train_losses) + 1),
        "train_loss": train_losses,
        "val_loss": val_losses,
        "val_mae": val_maes,
        "val_rmse": val_rmses,
    })
    history_path = MODEL_PATH / f"advanced_baseline_v3_NN_{MODEL_TAG}_training_history.parquet"
    history_df.write_parquet(history_path)
    print(f"Saved training history: {history_path}")

    device = get_torch_device()

    model, checkpoint = load_model_from_checkpoint(
        model_class=TaxiDemandAdvancedNN,
        checkpoint_path=(
            Path(MODEL_PATH)
            / f"advanced_baseline_v3_NN_{MODEL_TAG}_best_model.pt"
        ),
        device=device,
    )
    val_eval_df = collect_predictions(
        model,
        val_loader,
        device=device,
        embedding_input=False,
    )

    val_metrics_df = compute_regression_metrics(val_eval_df)
    print(val_metrics_df)

    figure, bucket_eval_df = plot_regression_diagnostics(
        val_eval_df
    )

    plt.show()
    print(bucket_eval_df)
    return {
        "model_tag": MODEL_TAG,
        "model_path": MODEL_PATH / f"advanced_baseline_v3_NN_{MODEL_TAG}_best_model.pt",
        "history_path": history_path,
        "metrics": val_metrics_df,
        "bucket_metrics": bucket_eval_df,
    }


training_results = {}
for dataset_config in DATASET_CONFIGS:
    result = train_dataset_v3(dataset_config)
    training_results[result["model_tag"]] = result

print("Completed models:", list(training_results))
# Out:
# New best model saved | Val MAE: 3.8819
# Epoch 001 | Train Loss: 0.3042 | Val Loss: 0.2264 | Val MAE: 3.8819 | Val RMSE: 17.7923 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 3.2600
# Epoch 002 | Train Loss: 0.2043 | Val Loss: 0.1897 | Val MAE: 3.2600 | Val RMSE: 19.9326 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.8967
# Epoch 003 | Train Loss: 0.1819 | Val Loss: 0.1763 | Val MAE: 2.8967 | Val RMSE: 13.7725 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.8050
# Epoch 004 | Train Loss: 0.1730 | Val Loss: 0.1715 | Val MAE: 2.8050 | Val RMSE: 23.0907 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.6668
# Epoch 005 | Train Loss: 0.1687 | Val Loss: 0.1686 | Val MAE: 2.6668 | Val RMSE: 10.9115 | LR: 0.001000 | No Improvement: 0/15
# Epoch 006 | Train Loss: 0.1658 | Val Loss: 0.1650 | Val MAE: 2.9149 | Val RMSE: 70.6629 | LR: 0.001000 | No Improvement: 1/15
# New best model saved | Val MAE: 2.6248
# Epoch 007 | Train Loss: 0.1640 | Val Loss: 0.1637 | Val MAE: 2.6248 | Val RMSE: 10.7594 | LR: 0.001000 | No Improvement: 0/15
# Epoch 008 | Train Loss: 0.1627 | Val Loss: 0.1625 | Val MAE: 2.6262 | Val RMSE: 10.9859 | LR: 0.001000 | No Improvement: 1/15
# New best model saved | Val MAE: 2.6023
# Epoch 009 | Train Loss: 0.1615 | Val Loss: 0.1611 | Val MAE: 2.6023 | Val RMSE: 27.8652 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.5438
# Epoch 010 | Train Loss: 0.1609 | Val Loss: 0.1608 | Val MAE: 2.5438 | Val RMSE: 10.2778 | LR: 0.001000 | No Improvement: 0/15
# Epoch 011 | Train Loss: 0.1603 | Val Loss: 0.1614 | Val MAE: 2.5750 | Val RMSE: 11.3735 | LR: 0.001000 | No Improvement: 1/15
# Epoch 012 | Train Loss: 0.1598 | Val Loss: 0.1594 | Val MAE: 2.5477 | Val RMSE: 10.4730 | LR: 0.001000 | No Improvement: 2/15
# Epoch 013 | Train Loss: 0.1593 | Val Loss: 0.1607 | Val MAE: 2.6725 | Val RMSE: 11.4740 | LR: 0.001000 | No Improvement: 3/15
# New best model saved | Val MAE: 2.4773
# Epoch 014 | Train Loss: 0.1590 | Val Loss: 0.1588 | Val MAE: 2.4773 | Val RMSE: 9.8654 | LR: 0.001000 | No Improvement: 0/15
# Epoch 015 | Train Loss: 0.1586 | Val Loss: 0.1599 | Val MAE: 2.7586 | Val RMSE: 11.9178 | LR: 0.001000 | No Improvement: 1/15
# Epoch 016 | Train Loss: 0.1585 | Val Loss: 0.1596 | Val MAE: 2.5033 | Val RMSE: 10.3166 | LR: 0.001000 | No Improvement: 2/15
# New best model saved | Val MAE: 2.4653
# Epoch 017 | Train Loss: 0.1581 | Val Loss: 0.1589 | Val MAE: 2.4653 | Val RMSE: 10.0101 | LR: 0.001000 | No Improvement: 0/15
# New best model saved | Val MAE: 2.4468
# Epoch 018 | Train Loss: 0.1580 | Val Loss: 0.1589 | Val MAE: 2.4468 | Val RMSE: 9.9493 | LR: 0.001000 | No Improvement: 0/15
# Epoch 019 | Train Loss: 0.1576 | Val Loss: 0.1582 | Val MAE: 2.4931 | Val RMSE: 10.1388 | LR: 0.001000 | No Improvement: 1/15
# Epoch 020 | Train Loss: 0.1576 | Val Loss: 0.1613 | Val MAE: 3.1465 | Val RMSE: 14.1385 | LR: 0.001000 | No Improvement: 2/15
# Epoch 021 | Train Loss: 0.1574 | Val Loss: 0.1576 | Val MAE: 2.4523 | Val RMSE: 10.0100 | LR: 0.001000 | No Improvement: 3/15
# Epoch 022 | Train Loss: 0.1573 | Val Loss: 0.1584 | Val MAE: 2.5485 | Val RMSE: 10.6480 | LR: 0.001000 | No Improvement: 4/15
# Epoch 023 | Train Loss: 0.1570 | Val Loss: 0.1575 | Val MAE: 2.5035 | Val RMSE: 21.8696 | LR: 0.001000 | No Improvement: 5/15
# New best model saved | Val MAE: 2.4118
# Epoch 024 | Train Loss: 0.1569 | Val Loss: 0.1571 | Val MAE: 2.4118 | Val RMSE: 9.5862 | LR: 0.001000 | No Improvement: 0/15
# Epoch 025 | Train Loss: 0.1568 | Val Loss: 0.1571 | Val MAE: 2.4417 | Val RMSE: 9.8662 | LR: 0.001000 | No Improvement: 1/15
# Epoch 026 | Train Loss: 0.1566 | Val Loss: 0.1581 | Val MAE: 2.4240 | Val RMSE: 9.7137 | LR: 0.001000 | No Improvement: 2/15
# Epoch 027 | Train Loss: 0.1565 | Val Loss: 0.1566 | Val MAE: 2.4579 | Val RMSE: 9.9916 | LR: 0.001000 | No Improvement: 3/15
# Epoch 028 | Train Loss: 0.1563 | Val Loss: 0.1572 | Val MAE: 2.5670 | Val RMSE: 10.4449 | LR: 0.001000 | No Improvement: 4/15
# Epoch 029 | Train Loss: 0.1563 | Val Loss: 0.1570 | Val MAE: 2.4257 | Val RMSE: 9.6819 | LR: 0.001000 | No Improvement: 5/15
# Epoch 030 | Train Loss: 0.1561 | Val Loss: 0.1573 | Val MAE: 2.4451 | Val RMSE: 9.7557 | LR: 0.000500 | No Improvement: 6/15
# New best model saved | Val MAE: 2.3794
# Epoch 031 | Train Loss: 0.1545 | Val Loss: 0.1551 | Val MAE: 2.3794 | Val RMSE: 9.5571 | LR: 0.000500 | No Improvement: 0/15
# Epoch 032 | Train Loss: 0.1544 | Val Loss: 0.1558 | Val MAE: 2.3962 | Val RMSE: 9.5328 | LR: 0.000500 | No Improvement: 1/15
# Epoch 033 | Train Loss: 0.1544 | Val Loss: 0.1557 | Val MAE: 2.5399 | Val RMSE: 10.3219 | LR: 0.000500 | No Improvement: 2/15
# New best model saved | Val MAE: 2.3626
# Epoch 034 | Train Loss: 0.1543 | Val Loss: 0.1552 | Val MAE: 2.3626 | Val RMSE: 9.4892 | LR: 0.000500 | No Improvement: 0/15
# New best model saved | Val MAE: 2.3539
# Epoch 035 | Train Loss: 0.1542 | Val Loss: 0.1548 | Val MAE: 2.3539 | Val RMSE: 9.4538 | LR: 0.000500 | No Improvement: 0/15
# Epoch 036 | Train Loss: 0.1542 | Val Loss: 0.1554 | Val MAE: 2.4766 | Val RMSE: 10.8490 | LR: 0.000500 | No Improvement: 1/15
# Epoch 037 | Train Loss: 0.1541 | Val Loss: 0.1546 | Val MAE: 2.3827 | Val RMSE: 9.5176 | LR: 0.000500 | No Improvement: 2/15
# Epoch 038 | Train Loss: 0.1541 | Val Loss: 0.1548 | Val MAE: 2.3555 | Val RMSE: 9.3131 | LR: 0.000500 | No Improvement: 3/15
# Epoch 039 | Train Loss: 0.1540 | Val Loss: 0.1544 | Val MAE: 2.3660 | Val RMSE: 9.4564 | LR: 0.000500 | No Improvement: 4/15
# Epoch 040 | Train Loss: 0.1540 | Val Loss: 0.1550 | Val MAE: 2.3987 | Val RMSE: 9.8646 | LR: 0.000500 | No Improvement: 5/15
# New best model saved | Val MAE: 2.3478
# Epoch 041 | Train Loss: 0.1539 | Val Loss: 0.1542 | Val MAE: 2.3478 | Val RMSE: 9.3822 | LR: 0.000500 | No Improvement: 0/15
# Epoch 042 | Train Loss: 0.1539 | Val Loss: 0.1550 | Val MAE: 2.4580 | Val RMSE: 9.9518 | LR: 0.000500 | No Improvement: 1/15
# Epoch 043 | Train Loss: 0.1539 | Val Loss: 0.1550 | Val MAE: 2.4266 | Val RMSE: 9.8791 | LR: 0.000500 | No Improvement: 2/15
# Epoch 044 | Train Loss: 0.1538 | Val Loss: 0.1547 | Val MAE: 2.3484 | Val RMSE: 9.3134 | LR: 0.000500 | No Improvement: 3/15
# Epoch 045 | Train Loss: 0.1538 | Val Loss: 0.1545 | Val MAE: 2.4085 | Val RMSE: 9.5910 | LR: 0.000500 | No Improvement: 4/15
# Epoch 046 | Train Loss: 0.1538 | Val Loss: 0.1544 | Val MAE: 2.3811 | Val RMSE: 9.5029 | LR: 0.000500 | No Improvement: 5/15
# Epoch 047 | Train Loss: 0.1537 | Val Loss: 0.1546 | Val MAE: 2.3662 | Val RMSE: 9.4598 | LR: 0.000250 | No Improvement: 6/15
# New best model saved | Val MAE: 2.3223
# Epoch 048 | Train Loss: 0.1528 | Val Loss: 0.1537 | Val MAE: 2.3223 | Val RMSE: 9.2363 | LR: 0.000250 | No Improvement: 0/15
# Epoch 049 | Train Loss: 0.1528 | Val Loss: 0.1538 | Val MAE: 2.3293 | Val RMSE: 9.2685 | LR: 0.000250 | No Improvement: 1/15
# Epoch 050 | Train Loss: 0.1528 | Val Loss: 0.1536 | Val MAE: 2.3317 | Val RMSE: 9.2861 | LR: 0.000250 | No Improvement: 2/15
# Epoch 051 | Train Loss: 0.1527 | Val Loss: 0.1539 | Val MAE: 2.3889 | Val RMSE: 9.5154 | LR: 0.000250 | No Improvement: 3/15
# New best model saved | Val MAE: 2.3214
# Epoch 052 | Train Loss: 0.1527 | Val Loss: 0.1537 | Val MAE: 2.3214 | Val RMSE: 9.2184 | LR: 0.000250 | No Improvement: 0/15
# New best model saved | Val MAE: 2.3203
# Epoch 053 | Train Loss: 0.1528 | Val Loss: 0.1535 | Val MAE: 2.3203 | Val RMSE: 9.1419 | LR: 0.000250 | No Improvement: 0/15
# New best model saved | Val MAE: 2.3187
# Epoch 054 | Train Loss: 0.1527 | Val Loss: 0.1536 | Val MAE: 2.3187 | Val RMSE: 9.1970 | LR: 0.000250 | No Improvement: 0/15
# New best model saved | Val MAE: 2.3175
# Epoch 055 | Train Loss: 0.1527 | Val Loss: 0.1535 | Val MAE: 2.3175 | Val RMSE: 9.2266 | LR: 0.000250 | No Improvement: 0/15
# Epoch 056 | Train Loss: 0.1527 | Val Loss: 0.1541 | Val MAE: 2.3459 | Val RMSE: 9.6293 | LR: 0.000250 | No Improvement: 1/15
# New best model saved | Val MAE: 2.3171
# Epoch 057 | Train Loss: 0.1526 | Val Loss: 0.1534 | Val MAE: 2.3171 | Val RMSE: 9.2353 | LR: 0.000250 | No Improvement: 0/15
# Epoch 058 | Train Loss: 0.1526 | Val Loss: 0.1534 | Val MAE: 2.3203 | Val RMSE: 9.1729 | LR: 0.000250 | No Improvement: 1/15
# New best model saved | Val MAE: 2.3079
# Epoch 059 | Train Loss: 0.1526 | Val Loss: 0.1534 | Val MAE: 2.3079 | Val RMSE: 9.1556 | LR: 0.000250 | No Improvement: 0/15
# Epoch 060 | Train Loss: 0.1526 | Val Loss: 0.1538 | Val MAE: 2.3429 | Val RMSE: 9.3226 | LR: 0.000250 | No Improvement: 1/15
# Epoch 061 | Train Loss: 0.1526 | Val Loss: 0.1536 | Val MAE: 2.3831 | Val RMSE: 9.5321 | LR: 0.000250 | No Improvement: 2/15
# Epoch 062 | Train Loss: 0.1525 | Val Loss: 0.1536 | Val MAE: 2.3523 | Val RMSE: 9.3998 | LR: 0.000250 | No Improvement: 3/15
# Epoch 063 | Train Loss: 0.1525 | Val Loss: 0.1535 | Val MAE: 2.3179 | Val RMSE: 9.2233 | LR: 0.000250 | No Improvement: 4/15
# Epoch 064 | Train Loss: 0.1525 | Val Loss: 0.1535 | Val MAE: 2.3144 | Val RMSE: 9.2342 | LR: 0.000250 | No Improvement: 5/15
# Epoch 065 | Train Loss: 0.1525 | Val Loss: 0.1537 | Val MAE: 2.3240 | Val RMSE: 9.3206 | LR: 0.000125 | No Improvement: 6/15
# Epoch 066 | Train Loss: 0.1520 | Val Loss: 0.1531 | Val MAE: 2.3149 | Val RMSE: 9.2253 | LR: 0.000125 | No Improvement: 7/15
# New best model saved | Val MAE: 2.2947
# Epoch 067 | Train Loss: 0.1520 | Val Loss: 0.1532 | Val MAE: 2.2947 | Val RMSE: 9.0907 | LR: 0.000125 | No Improvement: 0/15
# Epoch 068 | Train Loss: 0.1520 | Val Loss: 0.1531 | Val MAE: 2.3195 | Val RMSE: 9.1870 | LR: 0.000125 | No Improvement: 1/15
# New best model saved | Val MAE: 2.2924
# Epoch 069 | Train Loss: 0.1520 | Val Loss: 0.1529 | Val MAE: 2.2924 | Val RMSE: 9.0305 | LR: 0.000125 | No Improvement: 0/15
# Epoch 070 | Train Loss: 0.1519 | Val Loss: 0.1530 | Val MAE: 2.3148 | Val RMSE: 9.1668 | LR: 0.000125 | No Improvement: 1/15
# Epoch 071 | Train Loss: 0.1519 | Val Loss: 0.1530 | Val MAE: 2.3088 | Val RMSE: 9.2544 | LR: 0.000125 | No Improvement: 2/15
# Epoch 072 | Train Loss: 0.1519 | Val Loss: 0.1530 | Val MAE: 2.3006 | Val RMSE: 9.1069 | LR: 0.000125 | No Improvement: 3/15
# Epoch 073 | Train Loss: 0.1519 | Val Loss: 0.1530 | Val MAE: 2.3087 | Val RMSE: 9.1872 | LR: 0.000125 | No Improvement: 4/15
# Epoch 074 | Train Loss: 0.1519 | Val Loss: 0.1531 | Val MAE: 2.3129 | Val RMSE: 9.1995 | LR: 0.000125 | No Improvement: 5/15
# Epoch 075 | Train Loss: 0.1519 | Val Loss: 0.1530 | Val MAE: 2.2938 | Val RMSE: 9.1295 | LR: 0.000063 | No Improvement: 6/15
# Epoch 076 | Train Loss: 0.1517 | Val Loss: 0.1528 | Val MAE: 2.2967 | Val RMSE: 9.0660 | LR: 0.000063 | No Improvement: 7/15
# Epoch 077 | Train Loss: 0.1516 | Val Loss: 0.1528 | Val MAE: 2.2978 | Val RMSE: 9.0567 | LR: 0.000063 | No Improvement: 8/15
# Epoch 078 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2936 | Val RMSE: 9.0813 | LR: 0.000063 | No Improvement: 9/15
# Epoch 079 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2932 | Val RMSE: 9.0826 | LR: 0.000063 | No Improvement: 10/15
# Epoch 080 | Train Loss: 0.1516 | Val Loss: 0.1528 | Val MAE: 2.3001 | Val RMSE: 9.1039 | LR: 0.000063 | No Improvement: 11/15
# New best model saved | Val MAE: 2.2883
# Epoch 081 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2883 | Val RMSE: 9.0602 | LR: 0.000063 | No Improvement: 0/15
# Epoch 082 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2961 | Val RMSE: 9.0949 | LR: 0.000063 | No Improvement: 1/15
# New best model saved | Val MAE: 2.2876
# Epoch 083 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2876 | Val RMSE: 9.0602 | LR: 0.000063 | No Improvement: 0/15
# Epoch 084 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2889 | Val RMSE: 9.0800 | LR: 0.000063 | No Improvement: 1/15
# Epoch 085 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2942 | Val RMSE: 9.0972 | LR: 0.000063 | No Improvement: 2/15
# Epoch 086 | Train Loss: 0.1516 | Val Loss: 0.1527 | Val MAE: 2.2915 | Val RMSE: 9.1007 | LR: 0.000063 | No Improvement: 3/15
# Epoch 087 | Train Loss: 0.1516 | Val Loss: 0.1528 | Val MAE: 2.3006 | Val RMSE: 9.1069 | LR: 0.000063 | No Improvement: 4/15
# Epoch 088 | Train Loss: 0.1516 | Val Loss: 0.1526 | Val MAE: 2.2926 | Val RMSE: 9.0885 | LR: 0.000063 | No Improvement: 5/15
# Epoch 089 | Train Loss: 0.1516 | Val Loss: 0.1528 | Val MAE: 2.2955 | Val RMSE: 9.1067 | LR: 0.000031 | No Improvement: 6/15
# New best model saved | Val MAE: 2.2845
# Epoch 090 | Train Loss: 0.1514 | Val Loss: 0.1526 | Val MAE: 2.2845 | Val RMSE: 9.0489 | LR: 0.000031 | No Improvement: 0/15
# Epoch 091 | Train Loss: 0.1514 | Val Loss: 0.1526 | Val MAE: 2.2892 | Val RMSE: 9.0793 | LR: 0.000031 | No Improvement: 1/15
# Epoch 092 | Train Loss: 0.1514 | Val Loss: 0.1527 | Val MAE: 2.2957 | Val RMSE: 9.1271 | LR: 0.000031 | No Improvement: 2/15
# Epoch 093 | Train Loss: 0.1514 | Val Loss: 0.1526 | Val MAE: 2.2847 | Val RMSE: 9.0605 | LR: 0.000031 | No Improvement: 3/15
# Epoch 094 | Train Loss: 0.1514 | Val Loss: 0.1526 | Val MAE: 2.2889 | Val RMSE: 9.0631 | LR: 0.000031 | No Improvement: 4/15
# Epoch 095 | Train Loss: 0.1514 | Val Loss: 0.1526 | Val MAE: 2.2884 | Val RMSE: 9.0661 | LR: 0.000031 | No Improvement: 5/15
# Epoch 096 | Train Loss: 0.1514 | Val Loss: 0.1526 | Val MAE: 2.2885 | Val RMSE: 9.0557 | LR: 0.000016 | No Improvement: 6/15
# Epoch 097 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2862 | Val RMSE: 9.0675 | LR: 0.000016 | No Improvement: 7/15
# Epoch 098 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2865 | Val RMSE: 9.0471 | LR: 0.000016 | No Improvement: 8/15
# Epoch 099 | Train Loss: 0.1513 | Val Loss: 0.1526 | Val MAE: 2.2869 | Val RMSE: 9.0564 | LR: 0.000016 | No Improvement: 9/15
# New best model saved | Val MAE: 2.2837
# Epoch 100 | Train Loss: 0.1513 | Val Loss: 0.1526 | Val MAE: 2.2837 | Val RMSE: 9.0327 | LR: 0.000016 | No Improvement: 0/15
# New best model saved | Val MAE: 2.2832
# Epoch 101 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2832 | Val RMSE: 9.0285 | LR: 0.000016 | No Improvement: 0/15
# Epoch 102 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2877 | Val RMSE: 9.0422 | LR: 0.000016 | No Improvement: 1/15
# New best model saved | Val MAE: 2.2829
# Epoch 103 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2829 | Val RMSE: 9.0565 | LR: 0.000016 | No Improvement: 0/15
# Epoch 104 | Train Loss: 0.1513 | Val Loss: 0.1526 | Val MAE: 2.2844 | Val RMSE: 9.0472 | LR: 0.000016 | No Improvement: 1/15
# Epoch 105 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2871 | Val RMSE: 9.0541 | LR: 0.000016 | No Improvement: 2/15
# Epoch 106 | Train Loss: 0.1513 | Val Loss: 0.1526 | Val MAE: 2.2889 | Val RMSE: 9.0626 | LR: 0.000016 | No Improvement: 3/15
# Epoch 107 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2851 | Val RMSE: 9.0320 | LR: 0.000016 | No Improvement: 4/15
# Epoch 108 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2833 | Val RMSE: 9.0270 | LR: 0.000016 | No Improvement: 5/15
# New best model saved | Val MAE: 2.2824
# Epoch 109 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2824 | Val RMSE: 9.0364 | LR: 0.000016 | No Improvement: 0/15
# Epoch 110 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2829 | Val RMSE: 9.0230 | LR: 0.000016 | No Improvement: 1/15
# Epoch 111 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2846 | Val RMSE: 9.0490 | LR: 0.000016 | No Improvement: 2/15
# New best model saved | Val MAE: 2.2819
# Epoch 112 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2819 | Val RMSE: 9.0367 | LR: 0.000016 | No Improvement: 0/15
# Epoch 113 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2826 | Val RMSE: 9.0300 | LR: 0.000016 | No Improvement: 1/15
# Epoch 114 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2846 | Val RMSE: 9.0320 | LR: 0.000016 | No Improvement: 2/15
# Epoch 115 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2827 | Val RMSE: 9.0181 | LR: 0.000016 | No Improvement: 3/15
# New best model saved | Val MAE: 2.2810
# Epoch 116 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2810 | Val RMSE: 9.0176 | LR: 0.000016 | No Improvement: 0/15
# Epoch 117 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2850 | Val RMSE: 9.0478 | LR: 0.000016 | No Improvement: 1/15
# Epoch 118 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2838 | Val RMSE: 9.0168 | LR: 0.000016 | No Improvement: 2/15
# Epoch 119 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2819 | Val RMSE: 9.0269 | LR: 0.000016 | No Improvement: 3/15
# Epoch 120 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2827 | Val RMSE: 9.0437 | LR: 0.000016 | No Improvement: 4/15
# Epoch 121 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2824 | Val RMSE: 9.0244 | LR: 0.000016 | No Improvement: 5/15
# Epoch 122 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2851 | Val RMSE: 9.0346 | LR: 0.000008 | No Improvement: 6/15
# Epoch 123 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2831 | Val RMSE: 9.0121 | LR: 0.000008 | No Improvement: 7/15
# Epoch 124 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2815 | Val RMSE: 9.0302 | LR: 0.000008 | No Improvement: 8/15
# Epoch 125 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2829 | Val RMSE: 9.0346 | LR: 0.000008 | No Improvement: 9/15
# Epoch 126 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2828 | Val RMSE: 9.0336 | LR: 0.000008 | No Improvement: 10/15
# Epoch 127 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2834 | Val RMSE: 9.0424 | LR: 0.000008 | No Improvement: 11/15
# Epoch 128 | Train Loss: 0.1513 | Val Loss: 0.1525 | Val MAE: 2.2823 | Val RMSE: 9.0323 | LR: 0.000004 | No Improvement: 12/15
# Epoch 129 | Train Loss: 0.1512 | Val Loss: 0.1525 | Val MAE: 2.2815 | Val RMSE: 9.0253 | LR: 0.000004 | No Improvement: 13/15
# Epoch 130 | Train Loss: 0.1512 | Val Loss: 0.1525 | Val MAE: 2.2811 | Val RMSE: 9.0196 | LR: 0.000004 | No Improvement: 14/15
# Epoch 131 | Train Loss: 0.1512 | Val Loss: 0.1525 | Val MAE: 2.2821 | Val RMSE: 9.0272 | LR: 0.000004 | No Improvement: 15/15
# Early stopping at epoch 131. Best epoch was 116 with Val MAE: 2.2810
# Best Epoch: 116
# Best Val MAE: 2.2810

# %% [markdown]
# ### Load best model after training

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# ## Analyse model performance

# %%
# Executed inside train_dataset_v3 for every dataset configuration.

# %% [markdown]
# mean_residuals are > 0 => model is underpredicting the demand
